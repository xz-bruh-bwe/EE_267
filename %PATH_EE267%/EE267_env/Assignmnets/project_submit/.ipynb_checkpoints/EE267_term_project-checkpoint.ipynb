# %% [markdown]
# ### Project Part 1: Extract swimmers photos from swimmers video.
#     This kernel is associated with converting the swimmers video and then saving it to a specific file location

# %%
### Imports
import cv2
import os
import shutil

import time

# %%
# %pwd
# Out:
# 'C:\\Users\\Baron\\Desktop\\EE_267_Repo\\EE_267\\%PATH_EE267%\\EE267_env\\Assignmnets\\project_submit'

# %%
### Designated File Location
backstroke_video_location = "C:\\Users\\Baron\\Documents\\Grad_School\\EE_267\\term_project\\videos\\backstroke_video.mp4"
breathstroke_video_location = "C:\\Users\\Baron\\Documents\\Grad_School\\EE_267\\term_project\\videos\\breathstroke_video.mp4"
butterfly_video_location = "C:\\Users\\Baron\\Documents\\Grad_School\\EE_267\\term_project\\videos\\buttefly_video.mp4"

backstroke_pictures_location_raw = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\backstroke_pictures_raw" 
breathstroke_pictures_location_raw = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\breathstroke_pictures_raw" 
butterfly_pictures_location_raw = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\butterfly_pictures_raw"

# %%
### Extract frames function
def extract_frames(video_path, output_folder):
    # Extract the video file name without extension to use as a prefix
    video_name = os.path.splitext(os.path.basename(video_path))[0]

    # Check if the output folder exists, and if so, clear it
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)  # Remove all existing files in the folder
    os.makedirs(output_folder)  # Re-create the empty folder

    # Open the video file
    video_capture = cv2.VideoCapture(video_path)
    
    # Check if the video was opened successfully
    if not video_capture.isOpened():
        print("Error: Could not open video.")
        return

    frame_count = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_rate = int(video_capture.get(cv2.CAP_PROP_FPS))
    print(f"Total frames: {frame_count}, Frame rate: {frame_rate} fps")

    # Extract and save frames
    frame_index = 0
    while True:
        ret, frame = video_capture.read()
        if not ret:
            break
        
        # Define the filename for each frame with the video name as a prefix
        frame_filename = os.path.join(output_folder, f"{video_name}_frame_{frame_index:05d}.jpg")
        
        # Write the frame to the output folder
        cv2.imwrite(frame_filename, frame)
        
        print(f"Extracted frame {frame_index}")
        frame_index += 1

    # Release the video capture object
    video_capture.release()
    print(f"Frames saved to {output_folder}")

# %% [markdown]
# ### Run Function
# #extract_frames(video_path, output_folder)
# #-----------------------------------------
# #extract_frames(backstroke_video_location, backstroke_pictures_location_raw)
# #extract_frames(breathstroke_video_location, breathstroke_pictures_location_raw)
# #extract_frames(butterfly_video_location, butterfly_pictures_location_raw)

# %% [markdown]
# ### Project Part 2: Run the newly created pictures through an object detection model, and then a segnment anything
#     These kernels are associated with applying the segment anything model (SAM) to extract the swimmers from the background.
#     First the code needs to located the swimmers, and then segment them.

# %%
import cv2
import numpy as np
from PIL import Image

# Load the MobileNet SSD model
prototxt = r"C:\Users\Baron\Desktop\MobileNet-SSD\\deploy.prototxt"
caffemodel = r"C:\Users\Baron\Desktop\MobileNet-SSD\\mobilenet_iter_73000.caffemodel"

# %%
#===========================================
""" 
This is a comment Block
"""
#===========================================
def preprocess_image(image):
    # Convert image to YUV color space
    image_yuv = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)
    # Apply histogram equalization on the Y channel (luminance)
    image_yuv[:, :, 0] = cv2.equalizeHist(image_yuv[:, :, 0])
    # Convert back to BGR color space
    processed_image = cv2.cvtColor(image_yuv, cv2.COLOR_YUV2BGR)
    return processed_image

def gamma_correction(image, gamma=2):
    # Build a lookup table mapping pixel values [0, 255] to adjusted gamma values
    inv_gamma = 1.0 / gamma
    table = np.array([(i / 255.0) ** inv_gamma * 255 for i in np.arange(256)]).astype("uint8")
    # Apply gamma correction
    gamma_corrected_image = cv2.LUT(image, table)
    
    # Show the image after gamma correction
    ##cv2.imshow("Gamma Corrected Image", gamma_corrected_image)
    ##print("Showing Gamma Corrected Image...")
    ##cv2.waitKey(0)  # Wait for a key press
    ##cv2.destroyAllWindows()
    return gamma_corrected_image


def reduce_blue_channel(image, reduction_factor=0.4):
    
    if image is None:
        print("Error: Unable to load image.")
        return None

    # Split into BGR channels
    b, g, r = cv2.split(image)

    # Reduce the intensity of the blue channel
    b = (b * reduction_factor).astype('uint8')

    # Merge the channels back
    adjusted_image = cv2.merge((b, g, r))

    return adjusted_image

def crop_image(image):
    # Get current dimensions
    height, width = image.shape[:2]
    print(f"Original size: {width}x{height}")

    # Calculate cropping box (center crop)
    crop_width = width // 2
    crop_height = height // 3

    start_x = (width - crop_width) // 2
    start_y = (height - crop_height) // 2
    end_x = start_x + crop_width
    end_y = start_y + crop_height

    # Perform the crop
    cropped_image = image[start_y:end_y, start_x:end_x]
    print(f"Cropped image size: {crop_width}x{crop_height}")
    return cropped_image
    
def sharpen_image(image):
    # Define a sharpening kernel
    sharpening_kernel = np.array([[0, -1, 0],
                                   [-1, 5, -1],
                                   [0, -1, 0]])
    # Apply the sharpening kernel to the image
    sharpened_image = cv2.filter2D(image, -1, sharpening_kernel)
    return sharpened_image


def apply_median_filter(image, kernel_size=5):
    if kernel_size % 2 == 0:
        raise ValueError("Kernel size must be an odd number!")

    # Apply the median filter
    filtered_image = cv2.medianBlur(image, kernel_size)
    return filtered_image


def enhance_image(image): # Change back to image
#def enhance_image(input_path): # Change back to image
    # Apply histogram equalization
    #image = cv2.imread(input_path)
    
    image = preprocess_image(image)
    # Apply gamma correction
    image = gamma_correction(image, gamma=3)
    image = reduce_blue_channel(image, reduction_factor = .85)
    image = crop_image(image)

    # Show the final enhanced image
    #cv2.imshow("Enhanced Image", image)
    #print("Showing Enhanced Image...")
    #cv2.waitKey(0)  # Wait for a key press
    #cv2.destroyAllWindows()
    return image

# %% [markdown]
#  enhance_image(r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\butterfly_pictures_raw\buttefly_video_frame_00668.jpg");

# %%
# Function to process and display images one at a time
def process_and_display_images(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    
    # Check if the output folder exists, and if so, clear it
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)  # Remove all existing files in the folder
    os.makedirs(output_folder)  # Re-create the empty folder

   # Loop through all files in the input folder
    for filename in os.listdir(input_folder):
        # Construct full file path
        input_path = os.path.join(input_folder, filename)
        
        # Extract the file name and extension
        file_base, file_ext = os.path.splitext(filename)
        output_filename = f"{file_base}_pp{file_ext}"  # Add the '_pp' suffix
        output_path = os.path.join(output_folder, output_filename)

        # Check if it is a file and has an image extension
        if os.path.isfile(input_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            # Read the image
            image = cv2.imread(input_path)
            if image is not None:
                # Enhance the image
                enhanced_image = enhance_image(image)
                
                # Save the enhanced image to the output folder
                cv2.imwrite(output_path, enhanced_image)
                print(f"Processed and saved: {output_path}")
            else:
                print(f"Failed to read image: {input_path}")

# %%
# Example usage
backstroke_pictures_location_raw = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\backstroke_pictures_raw" 
breathstroke_pictures_location_raw = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\breathstroke_pictures_raw" 
butterfly_pictures_location_raw = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\butterfly_pictures_raw" 

backstroke_pictures_location_pp = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp"
breathstroke_pictures_location_pp = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\breathstroke_pictures_pp"
butterfly_pictures_location_pp = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp"

#process_and_display_images(backstroke_pictures_location_raw, backstroke_pictures_location_pp)
#process_and_display_images(breathstroke_pictures_location_raw, breathstroke_pictures_location_pp)
process_and_display_images(butterfly_pictures_location_raw, butterfly_pictures_location_pp)
print("finished")
# Out:
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00000_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00001_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00002_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00003_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00004_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00005_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00006_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00007_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00008_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00009_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00010_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00011_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00012_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00013_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00014_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00015_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00016_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00017_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00018_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00019_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00020_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00021_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00022_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00023_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00024_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00025_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00026_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00027_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00028_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00029_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00030_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00031_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00032_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00033_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00034_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00035_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00036_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00037_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00038_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00039_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00040_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00041_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00042_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00043_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00044_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00045_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00046_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00047_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00048_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00049_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00050_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00051_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00052_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00053_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00054_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00055_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00056_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00057_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00058_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00059_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00060_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00061_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00062_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00063_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00064_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00065_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00066_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00067_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00068_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00069_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00070_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00071_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00072_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00073_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00074_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00075_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00076_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00077_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00078_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00079_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00080_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00081_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00082_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00083_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00084_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00085_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00086_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00087_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00088_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00089_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00090_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00091_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00092_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00093_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00094_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00095_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00096_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00097_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00098_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00099_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00100_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00101_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00102_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00103_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00104_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00105_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00106_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00107_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00108_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00109_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00110_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00111_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00112_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00113_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00114_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00115_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00116_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00117_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00118_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00119_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00120_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00121_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00122_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00123_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00124_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00125_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00126_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00127_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00128_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00129_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00130_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00131_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00132_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00133_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00134_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00135_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00136_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00137_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00138_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00139_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00140_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00141_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00142_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00143_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00144_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00145_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00146_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00147_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00148_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00149_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00150_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00151_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00152_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00153_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00154_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00155_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00156_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00157_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00158_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00159_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00160_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00161_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00233_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00234_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00235_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00236_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00237_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00238_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00239_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00240_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00241_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00242_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00243_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00244_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00245_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00246_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00247_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00248_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00249_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00250_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00251_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00252_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00253_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00254_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00255_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00256_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00257_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00258_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00259_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00260_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00261_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00262_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00263_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00264_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00265_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00266_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00267_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00268_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00269_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00270_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00271_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00272_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00273_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00274_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00275_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00276_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00277_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00278_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00279_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_00280_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# ...
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01117_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01118_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01119_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01120_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01121_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01122_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01123_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01124_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01125_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01126_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01127_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01128_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01129_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01130_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01131_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01132_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01133_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01134_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01135_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01136_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01137_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01138_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01139_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01140_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01141_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01142_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01143_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01144_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01145_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01146_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01147_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01148_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01149_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01150_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01151_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01152_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01153_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01154_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01155_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01156_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01157_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01158_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01159_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01160_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01161_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01162_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01163_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01164_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01165_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01166_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01167_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01168_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01169_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01170_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01171_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01172_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01173_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01174_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01175_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01176_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01177_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01178_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01179_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01180_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01181_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01182_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01183_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01184_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01185_pp.jpg
# Original size: 1280x720
# Cropped image size: 640x240
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01186_pp.jpg
# finished

# %% [markdown]
# ### COLAPSED

# %%
pip cache purge
# Out:
# Files removed: 0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: No matching packages

# %%
#pip install mediapipe==0.10.14 --user

# %%
import cv2
import mediapipe as mp
import numpy as np

# Initialize MediaPipe BlazePose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, model_complexity=1, enable_segmentation=True , min_detection_confidence=0.3, min_tracking_confidence=0.2)

def detect_swimmer_with_blazepose(image_path, debugging=True):
    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Failed to load image {image_path}")
        return None, None

    # Create a copy of the image for visualization (to avoid modifying the original image)
    visual_image = image.copy()

    # Convert the image to RGB (MediaPipe requires RGB input)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Process the image with BlazePose
    results = pose.process(image_rgb)

    # Get image dimensions
    h, w, _ = image.shape

    # Draw grid for visualization (optional)
    grid_color = (255, 255, 255)  # White color for the grid
    num_rows, num_cols = 10, 10  # Define grid dimensions
    for row in range(1, num_rows):
        y = row * h // num_rows
        cv2.line(visual_image, (0, y), (w, y), grid_color, 1)
    for col in range(1, num_cols):
        x = col * w // num_cols
        cv2.line(visual_image, (x, 0), (x, h), grid_color, 1)

    # List to store detected keypoints
    detected_points = []

    # Extract landmarks (key points) if they exist
    if results.pose_landmarks:
        for idx, landmark in enumerate(results.pose_landmarks.landmark):
            # Convert normalized coordinates to pixel coordinates
            x = int(landmark.x * w)
            y = int(landmark.y * h)
            confidence = landmark.visibility

            # Append the keypoint (x, y) to the list
            detected_points.append([x, y])

            # Visualize the keypoints on the visualization image
            if confidence > 0.5:  # Only draw points with good visibility
                cv2.circle(visual_image, (x, y), 5, (0, 255, 0), -1)  # Green dots for keypoints
                cv2.putText(visual_image, str(idx), (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 255, 0), 1)
        
    # Handle the case when no points are detected
    if not detected_points:
        print("No swimmer detected.")
        return None, visual_image
    if (debugging == True):
        return np.array(detected_points), visual_image  # Return unmodified original image
    else:
        return np.array(detected_points), image 
# Initialize MediaPipe BlazePose

# %%
pose.close()

# %%
# Initialize MediaPipe BlazePos
# Example usage (DELETE LATER FOR TESTING PURPOSES ONLY
#detected_point, processed_image = detect_swimmer_with_blazepose(r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00603_pp.jpg", debugging=True)


#detected_point, processed_image = detect_swimmer_with_blazepose(r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\breathstroke_pictures_pp\breathstroke_video_frame_00289_pp.jpg", debugging=True)
detected_point, processed_image = detect_swimmer_with_blazepose(r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp\buttefly_video_frame_01012_pp.jpg", debugging=True)

# Display the final image
cv2.imshow("Processed Image with Grid", processed_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Initialize MediaPipe BlazePose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, model_complexity=2, enable_segmentation=False , min_detection_confidence=0.2, min_tracking_confidence=0.2)

# %% [markdown]
# ### Swimmer Segmentation

# %%
import torch
from torchvision import models, transforms
import torchvision
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
from segment_anything import sam_model_registry, SamPredictor

# %%
def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)
    
def show_points(coords, labels, ax, marker_size=375):
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color='green', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color='red', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)   
    
def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))

# %%
def detect_and_segment_swimmer(image_path, model_checkpoint, model_type="vit_h", device="cpu"):


    # Detect swimmer using BlazePose
    detected_points, detected_image = detect_swimmer_with_blazepose(image_path, debugging=False)

    if detected_points is None:
        print("No swimmer detected.")
        return

    # Initialize SAM model
    sam = sam_model_registry[model_type](checkpoint=model_checkpoint)
    sam.to(device=device)
    predictor = SamPredictor(sam)

    # Set SAM's input image
    predictor.set_image(detected_image)

    # Use detected swimmer points as input for SAM
    input_point = detected_points
    input_label = np.array([1] * len(detected_points))  # Positive label for all points

    # Perform SAM prediction
    masks, scores, logits = predictor.predict(
        point_coords=input_point,
        point_labels=input_label,
        multimask_output=False,
    )

    # Visualize the results
    for i, (mask, score) in enumerate(zip(masks, scores)):
        plt.figure(figsize=(10, 10))
        plt.imshow(detected_image)
        show_mask(mask, plt.gca())
        show_points(input_point, input_label, plt.gca())
        plt.title(f"Mask {i + 1}, Score: {score:.3f}", fontsize=18)
        plt.axis('off')
        plt.show()

# %%
# Usage example

sam_checkpoint = "C:/Users/Baron/Desktop/EE_267_Repo/EE_267/%PATH_EE267%/EE267_env/checkpoint/sam_vit_h_4b8939.pth"

#detect_and_segment_swimmer(r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00023_pp.jpg", sam_checkpoint)
#detect_and_segment_swimmer(r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\breathstroke_pictures_pp\breathstroke_video_frame_00289_pp.jpg", sam_checkpoint)
detect_and_segment_swimmer(r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\\butterfly_pictures_pp\buttefly_video_frame_00468_pp.jpg", sam_checkpoint)
# Out:
# C:\Users\Baron\anaconda3\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# c:\users\baron\desktop\segment-anything\segment_anything\build_sam.py:105: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(f)

# %% [markdown]
# ### Swimmer Segmentation FINAL

# %%
import torch
from torchvision import models, transforms
import torchvision
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
from segment_anything import sam_model_registry, SamPredictor

# %%
def segment_swimmer_images(input_folder, output_folder, sam_checkpoint, model_type="vit_h", device="cpu"):
    """
    Processes images in the input folder, applies swimmer detection and segmentation,
    and saves the results in the output folder.

    Parameters:
    - input_folder: Folder containing input images.
    - output_folder: Folder to save the segmented images.
    - sam_checkpoint: Path to the SAM model checkpoint.
    - model_type: SAM model type (default: "vit_h").
    - device: Device to run the SAM model on (default: "cpu").
    """
    # Load SAM model for segmentation
    sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
    sam.to(device=device)
    predictor = SamPredictor(sam)
    
    # Check if the output folder exists, and if so, clear it
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)  # Remove all existing files in the folder
    os.makedirs(output_folder)  # Re-create the empty folder
    
    for filename in os.listdir(input_folder):
        image_path = os.path.join(input_folder, filename)
        
        # Detect swimmer in the image using BlazePose
        detected_points, image = detect_swimmer_with_blazepose(image_path, debugging=False)

        
        if detected_points is None or image is None:
            print(f"No swimmer detected in {filename}. Skipping...")
            continue  # Skip this image if no swimmer detected
        
        # Set SAM's input image
        predictor.set_image(image)
    
        # Use detected swimmer points as input for SAM
        input_point = detected_points
        input_label = np.array([1] * len(detected_points))  # Positive label for all points

        
        
        # Convert to RGB for SAM model
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        predictor.set_image(image_rgb)
        
        # Use SAM for segmentation with multimask_output set to False
        masks, scores, logits = predictor.predict(
            point_coords=input_point,
            point_labels=input_label,
            multimask_output=False  # Produce multiple masks
        )

        # Apply the mask to the image
        mask = masks[0]  # Retrieve the single mask
        mask_image = image_rgb * mask[..., np.newaxis]
        mask_image_bgr = cv2.cvtColor(mask_image, cv2.COLOR_RGB2BGR)
        
        # Save the segmented image
        output_filename = f"{os.path.splitext(filename)[0]}_segmented.jpg"
        output_path = os.path.join(output_folder, output_filename)
        cv2.imwrite(output_path, mask_image_bgr)
        print(f"Saved segmented image {output_filename}")

# %%
# Usage example
sam_checkpoint = "C:/Users/Baron/Desktop/EE_267_Repo/EE_267/%PATH_EE267%/EE267_env/checkpoint/sam_vit_h_4b8939.pth"


#Preprocessed Locations
backstroke_pictures_location_pp = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp" 
breathstroke_pictures_location_pp = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\breathstroke_pictures_pp" 
butterfly_pictures_location_pp = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp"  


## Endpoint Folders
backstroke_pictures_location_seg = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\segmented\backstroke_pictures_seg" 
breathstroke_pictures_location_seg = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\segmented\breathstroke_pictures_seg" 
butterfly_pictures_location_seg = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\segmented\butterfly_pictures_seg"  

# ---------------- BACKSTROKE RUN
segment_swimmer_images(backstroke_pictures_location_pp, backstroke_pictures_location_seg, sam_checkpoint)
# --------> BUTTERFLY RUN
segment_swimmer_images(butterfly_pictures_location_pp, butterfly_pictures_location_seg, sam_checkpoint)
# Out:
# Saved segmented image backstroke_video_frame_00598_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00599_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00600_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00601_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00602_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00603_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00604_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00605_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00606_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00607_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00608_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00609_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00610_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00611_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00612_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00613_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00614_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00615_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00616_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00617_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00618_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00619_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00620_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00621_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00622_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00623_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00624_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00625_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00626_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00627_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00628_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00629_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00630_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00631_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00632_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00633_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00634_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00635_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00636_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00637_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00638_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00639_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00640_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00641_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00642_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00643_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00644_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00645_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00646_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00647_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00648_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00649_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00650_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00651_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00652_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00653_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00654_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00655_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00656_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00657_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00658_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00659_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00660_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00661_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00662_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00663_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00664_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00665_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00666_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00667_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00668_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00669_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00670_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00671_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00672_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00673_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00674_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00675_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00676_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00677_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00678_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00679_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00680_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00681_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00682_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00683_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00684_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00685_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00686_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00687_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00688_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00689_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00690_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00691_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00692_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00693_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00694_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00695_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00696_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00697_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00698_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00699_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00700_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00701_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00702_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00703_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00704_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00705_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00706_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00707_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00708_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00709_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00710_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00711_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00712_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00713_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00714_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00715_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00716_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00717_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00718_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00719_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00720_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00721_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00722_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00723_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00724_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00725_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00726_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00727_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00827_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00828_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00829_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00830_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00831_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00832_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00833_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00834_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00835_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00836_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00837_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00838_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00839_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00840_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00841_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00842_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00843_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00844_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00845_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00846_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00847_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00848_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00849_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00850_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00851_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00852_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00853_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00854_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00855_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00856_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00857_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00858_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00859_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00860_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00861_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00862_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_00863_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00864_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00865_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00866_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_00867_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_00868_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01070_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01071_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01072_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_01073_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01074_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01075_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01076_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01077_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01078_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_01079_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01189_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01190_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01191_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01192_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01193_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01194_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01195_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01196_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01197_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01198_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01199_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01200_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01201_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01202_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01203_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01204_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_01205_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01206_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01207_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01208_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01209_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01210_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01211_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01212_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_01213_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01214_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01215_pp.jpg. Skipping...
# Saved segmented image backstroke_video_frame_01216_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01217_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01218_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01219_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01220_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01221_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01222_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01223_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01224_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01225_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01226_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01227_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01228_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01229_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01230_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01231_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01232_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01233_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01234_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01235_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01236_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01237_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01238_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01239_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01240_pp_segmented.jpg
# Saved segmented image backstroke_video_frame_01241_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01242_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01243_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01244_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01245_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in backstroke_video_frame_01246_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00000_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00001_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00002_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00003_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00004_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00005_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00006_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00007_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00008_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00009_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00010_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00011_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00012_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00013_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00014_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00015_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00016_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00017_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00018_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00019_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00020_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00021_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00022_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00023_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00024_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00025_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00026_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00027_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00028_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00029_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00030_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00031_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00032_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00033_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00034_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00035_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00036_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00037_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00038_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00039_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00040_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00041_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00042_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00043_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00044_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00045_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00046_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00047_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00048_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00049_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00050_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00051_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00052_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00053_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00054_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00055_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00056_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00057_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00058_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00059_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00060_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00061_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00062_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00063_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00064_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00065_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00066_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00067_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00068_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00069_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00070_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00071_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00072_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00073_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00074_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00075_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00076_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00077_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00078_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00079_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00080_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00081_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00082_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00083_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00084_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00085_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00086_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00087_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00088_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00089_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00090_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00091_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00092_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00093_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00094_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00095_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00096_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00097_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00098_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00099_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00100_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00101_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00102_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00103_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00104_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00105_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00106_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00107_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00108_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00109_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00110_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00111_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00112_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00113_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00114_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00115_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00116_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00117_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00118_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00119_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00120_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00121_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00122_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00123_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00124_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00125_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00126_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00127_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00128_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00129_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00130_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00131_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00132_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00133_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00134_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00135_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00136_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00137_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00138_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00139_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00140_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00141_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00142_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00143_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00144_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00145_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00146_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00147_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00148_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00149_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00150_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00151_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00152_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00153_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00154_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00155_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00156_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00157_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00158_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00159_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00160_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00161_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00233_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00234_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00235_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00236_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00237_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00238_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00239_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00240_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00241_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00242_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00243_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00244_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00245_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00246_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00247_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00248_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00249_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00250_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00251_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00252_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00253_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00254_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00255_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00256_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00257_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00258_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00259_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00260_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00261_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00262_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00263_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00264_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00265_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00266_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00267_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00268_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00269_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00270_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00271_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00272_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00273_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00274_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00275_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00276_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00277_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00278_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00279_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00280_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00281_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00282_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00283_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00284_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00285_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00286_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00287_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00288_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00289_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00290_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00291_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00292_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00293_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00294_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00295_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00296_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00297_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00298_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00299_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00300_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00301_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00302_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00303_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00304_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00305_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00306_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00307_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00308_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00309_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00310_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00311_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00312_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00313_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00314_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00315_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00316_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00317_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00318_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00319_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00320_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00321_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00322_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00323_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00324_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00325_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00326_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00327_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00328_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00329_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00330_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00331_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00332_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00333_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00334_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00335_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00336_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00337_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00338_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00339_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00340_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00341_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00342_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00343_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00344_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00345_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00346_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00347_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00348_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00349_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00350_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00351_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00352_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00435_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00436_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00437_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00438_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00439_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00440_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00441_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00442_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00443_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00444_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00445_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00446_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00447_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00448_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00449_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00450_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00451_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00452_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00453_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00454_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00455_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00456_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00457_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00458_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00459_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00460_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00461_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00462_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00463_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00464_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00465_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00466_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00467_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00468_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00469_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00470_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00471_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00472_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00473_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00474_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00475_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00476_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00477_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00478_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00479_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00480_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00481_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00482_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00483_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00484_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00485_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00486_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00487_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00488_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00489_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00490_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00491_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00492_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00493_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00494_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00495_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00496_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00497_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00498_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00499_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00500_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00501_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00502_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00503_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00504_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00505_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00506_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00507_pp_segmented.jpg
# No swimmer detected.
# ...
# No swimmer detected in buttefly_video_frame_00821_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00822_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00823_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00824_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00825_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00826_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00827_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00828_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00829_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00830_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00831_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00832_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00833_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00834_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00835_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00836_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00837_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00838_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00839_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00840_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00841_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00842_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00843_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00844_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00961_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00962_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00963_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00964_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00965_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00966_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00967_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00968_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00969_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00970_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00971_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00972_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00973_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00974_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00975_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00976_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00977_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00978_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00979_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00980_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00981_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00982_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00983_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00984_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00985_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00986_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00987_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00988_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00989_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00990_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00991_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00992_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00993_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00994_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00995_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_00996_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_00997_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00998_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_00999_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01000_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01001_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01002_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01003_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01004_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01005_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01006_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01007_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01008_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01009_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01010_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01011_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01012_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01013_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01014_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01015_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01016_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01017_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01018_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01019_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01020_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01021_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01022_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01023_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01024_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01025_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01026_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01027_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01028_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01029_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01030_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01031_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01032_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01033_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01034_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01035_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01036_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01037_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01084_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01085_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01086_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01087_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01088_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01089_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01090_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01091_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01092_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01093_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01094_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01095_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01096_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01097_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01098_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01099_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01100_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01101_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01102_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01103_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01104_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01105_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01106_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01107_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01108_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01109_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01110_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01111_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01112_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01113_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01114_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01115_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01116_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01117_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01118_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01119_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01120_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01121_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01122_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01123_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01124_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01125_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01126_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01127_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01128_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01129_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01130_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01131_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01132_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01133_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01134_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01135_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01136_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01137_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01138_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01139_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01140_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01141_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01142_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01143_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01144_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01145_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01146_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01147_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01148_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01149_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01150_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01151_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01152_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01153_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01154_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01155_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01156_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01157_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01158_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01159_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01160_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01161_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01162_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01163_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01164_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01165_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01166_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01167_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01168_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01169_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01170_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01171_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01172_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01173_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01174_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01175_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01176_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01177_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01178_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01179_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01180_pp.jpg. Skipping...
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01181_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01182_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01183_pp_segmented.jpg
# Saved segmented image buttefly_video_frame_01184_pp_segmented.jpg
# No swimmer detected.
# No swimmer detected in buttefly_video_frame_01185_pp.jpg. Skipping...
# Saved segmented image buttefly_video_frame_01186_pp_segmented.jpg

# %% [markdown]
# ### DO NOT UNCOMMENT
# #segment_swimmer_images(breathstroke_pictures_location_pp, breathstroke_pictures_location_seg, sam_checkpoint)
#
# # --------> BUTTERFLY RUN
# #segment_swimmer_images(butterfly_pictures_location_pp, butterfly_pictures_location_seg, sam_checkpoint)
