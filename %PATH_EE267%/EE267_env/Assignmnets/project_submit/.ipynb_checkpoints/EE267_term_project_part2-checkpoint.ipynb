# %% [markdown]
# ### Project Part 2: Pose Estimation on the Segmented Swimmer
#     Use Yolov7 to detect the swimmers joints and model the post estimation

# %%
pip install numpy==1.20.3

# %%
import torch
import torchvision
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
import yaml

# %%
import sys
# Add the path to your YOLOv7 repository to the Python path
sys.path.append(r"C:/Users/Baron/Desktop/yolov7")

# Now, you can import the module or class you need
from models.yolo import Model  # Replace 'yolov7' with the actual model class name

# %%
 map_location=torch.device('cpu')

# %%
### Practice on one Image

# %%
import torch
import cv2
import numpy as np
from torchvision import transforms
from utils.datasets import letterbox
from utils.general import non_max_suppression_kpt
from utils.plots import output_to_keypoint, plot_skeleton_kpts

def load_yolov7_model(weights_path, device):
    """
    Loads the YOLOv7 pose estimation model.
    Args:
        weights_path (str): Path to the YOLOv7 weights file.
        device (torch.device): The device to load the model on.
    Returns:
        model: Loaded YOLOv7 model.
    """
    # Load the model weights
    model_weights = torch.load(weights_path, map_location=device)
    model = model_weights['model']
    model.float().eval()

    # If CUDA is available, convert the model to half precision for faster inference
    if torch.cuda.is_available():
        model.half().to(device)
    return model

def detect_swimmer_pose(image_path, model, device):
    """
    Detects swimmer pose from an image using the YOLOv7 pose estimation model.
    Args:
        image_path (str): Path to the input image.
        model: Loaded YOLOv7 model.
        device (torch.device): The device to perform inference on.
    Returns:
        image_with_kpts: Image with keypoints and skeleton plotted.
        keypoints: Array of detected keypoints.
    """
    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Error: Unable to load image from {image_path}")
        return None, None

    # Resize and pad the image to meet YOLOv7 requirements
    resized_image = letterbox(image, 960, stride=64, auto=True)[0]
    original_image = resized_image.copy()

    # Convert the image to a tensor
    transformed_image = transforms.ToTensor()(resized_image)
    transformed_image = torch.tensor(np.array([transformed_image.numpy()]))

    # Move the image to the device and convert to half precision if CUDA is available
    if torch.cuda.is_available():
        transformed_image = transformed_image.half().to(device)

    # Perform inference
    with torch.no_grad():
        output, _ = model(transformed_image)

    # Apply Non-Max Suppression to extract keypoints
    output = non_max_suppression_kpt(output, 0.25, 0.65, nc=model.yaml['nc'], nkpt=model.yaml['nkpt'], kpt_label=True)

    # Convert output to keypoint format
    with torch.no_grad():
        keypoints = output_to_keypoint(output)

    # Draw the skeleton and keypoints on the image
    for idx in range(keypoints.shape[0]):
        plot_skeleton_kpts(original_image, keypoints[idx, 7:].T, 3)

    return original_image, keypoints

def run_pose_estimation(image_path, weights_path):
    """
    Runs YOLOv7 pose estimation on the given image.
    Args:
        image_path (str): Path to the image for pose estimation.
        weights_path (str): Path to the YOLOv7 pose estimation weights file.
    Returns:
        image_with_kpts: Processed image with keypoints and skeleton plotted.
        keypoints: Array of detected keypoints.
    """
    # Load YOLOv7 model
    device = torch.device("cuda:0" if torch.cuda.is_available() else 'cpu')
    model = load_yolov7_model(weights_path, device)

    # Detect swimmer pose
    image_with_kpts, keypoints = detect_swimmer_pose(image_path, model, device)

    return image_with_kpts, keypoints

# %%
# Call the function
image_path = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\segmented\breathstroke_pictures_seg\breathstroke_video_frame_00112_pp_segmented.jpg"  # Replace with the path to your segmented swimmer image
weights_path = 'C:/Users/Baron/Desktop/yolov7/yolov7-w6-pose.pt'  # Replace with your YOLOv7 weights path

processed_image, keypoints = run_pose_estimation(image_path, weights_path)

cv2.imshow("Swimmer Pose Estimation", processed_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# C:\Users\Baron\AppData\Local\Temp\ipykernel_29624\3814058545.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_weights = torch.load(weights_path, map_location=device)

# %%
import os
import shutil
import cv2

def process_folder_images(input_folder, output_folder, weights_path):
    """
    Processes all images in the input folder using YOLOv7 pose estimation and saves the 
    processed images with keypoints to the output folder. Clears the output folder before running.
    
    Args:
        input_folder (str): Path to the folder containing input images.
        output_folder (str): Path to the folder to save processed images.
        weights_path (str): Path to the YOLOv7 weights file.
    """
    # Ensure the output folder is cleared before running
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)
    os.makedirs(output_folder, exist_ok=True)

    # Load the YOLOv7 model
    device = torch.device("cuda:0" if torch.cuda.is_available() else 'cpu')
    model = load_yolov7_model(weights_path, device)

    # Process each image in the input folder
    for filename in os.listdir(input_folder):
        input_path = os.path.join(input_folder, filename)

        # Ensure the file is an image
        if not filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            print(f"Skipping non-image file: {filename}")
            continue

        print(f"Processing {filename}...")

        # Perform pose estimation
        processed_image, keypoints = detect_swimmer_pose(input_path, model, device)
        
        if processed_image is None:
            print(f"Skipping {filename} due to an error in pose estimation.")
            continue

        # Save the processed image to the output folder
        output_path = os.path.join(output_folder, filename)
        cv2.imwrite(output_path, processed_image)

        # Append keypoints information if needed (e.g., save to a log file)
        with open(os.path.join(output_folder, "keypoints_log.txt"), "a") as log_file:
            log_file.write(f"{filename}: {keypoints}\n")

    print("Processing complete. Processed images saved to:", output_folder)

# %%
weights_path = 'C:/Users/Baron/Desktop/yolov7/yolov7-w6-pose.pt'  # Replace with your YOLOv7 weights path

breathstroke_pictures_location_seg = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\segmented\breathstroke_pictures_seg" 

breathstroke_pictures_location_POSE = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\POSE\breathstroke_POSE" 

process_folder_images(breathstroke_pictures_location_seg, breathstroke_pictures_location_POSE, weights_path)
# Out:
# C:\Users\Baron\AppData\Local\Temp\ipykernel_29624\3814058545.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_weights = torch.load(weights_path, map_location=device)
# Processing breathstroke_video_frame_00040_pp_segmented.jpg...
# Processing breathstroke_video_frame_00048_pp_segmented.jpg...
# Processing breathstroke_video_frame_00053_pp_segmented.jpg...
# Processing breathstroke_video_frame_00054_pp_segmented.jpg...
# Processing breathstroke_video_frame_00056_pp_segmented.jpg...
# Processing breathstroke_video_frame_00058_pp_segmented.jpg...
# Processing breathstroke_video_frame_00063_pp_segmented.jpg...
# Processing breathstroke_video_frame_00064_pp_segmented.jpg...
# Processing breathstroke_video_frame_00065_pp_segmented.jpg...
# Processing breathstroke_video_frame_00066_pp_segmented.jpg...
# Processing breathstroke_video_frame_00067_pp_segmented.jpg...
# Processing breathstroke_video_frame_00068_pp_segmented.jpg...
# Processing breathstroke_video_frame_00069_pp_segmented.jpg...
# Processing breathstroke_video_frame_00070_pp_segmented.jpg...
# Processing breathstroke_video_frame_00071_pp_segmented.jpg...
# Processing breathstroke_video_frame_00072_pp_segmented.jpg...
# Processing breathstroke_video_frame_00073_pp_segmented.jpg...
# Processing breathstroke_video_frame_00074_pp_segmented.jpg...
# Processing breathstroke_video_frame_00075_pp_segmented.jpg...
# Processing breathstroke_video_frame_00076_pp_segmented.jpg...
# Processing breathstroke_video_frame_00077_pp_segmented.jpg...
# Processing breathstroke_video_frame_00078_pp_segmented.jpg...
# Processing breathstroke_video_frame_00079_pp_segmented.jpg...
# Processing breathstroke_video_frame_00080_pp_segmented.jpg...
# Processing breathstroke_video_frame_00081_pp_segmented.jpg...
# Processing breathstroke_video_frame_00082_pp_segmented.jpg...
# Processing breathstroke_video_frame_00083_pp_segmented.jpg...
# Processing breathstroke_video_frame_00084_pp_segmented.jpg...
# Processing breathstroke_video_frame_00086_pp_segmented.jpg...
# Processing breathstroke_video_frame_00087_pp_segmented.jpg...
# Processing breathstroke_video_frame_00090_pp_segmented.jpg...
# Processing breathstroke_video_frame_00093_pp_segmented.jpg...
# Processing breathstroke_video_frame_00094_pp_segmented.jpg...
# Processing breathstroke_video_frame_00095_pp_segmented.jpg...
# Processing breathstroke_video_frame_00096_pp_segmented.jpg...
# Processing breathstroke_video_frame_00097_pp_segmented.jpg...
# Processing breathstroke_video_frame_00098_pp_segmented.jpg...
# Processing breathstroke_video_frame_00099_pp_segmented.jpg...
# Processing breathstroke_video_frame_00104_pp_segmented.jpg...
# Processing breathstroke_video_frame_00105_pp_segmented.jpg...
# Processing breathstroke_video_frame_00106_pp_segmented.jpg...
# Processing breathstroke_video_frame_00108_pp_segmented.jpg...
# Processing breathstroke_video_frame_00109_pp_segmented.jpg...
# Processing breathstroke_video_frame_00110_pp_segmented.jpg...
# Processing breathstroke_video_frame_00111_pp_segmented.jpg...
# Processing breathstroke_video_frame_00112_pp_segmented.jpg...
# Processing breathstroke_video_frame_00113_pp_segmented.jpg...
# Processing breathstroke_video_frame_00114_pp_segmented.jpg...
# Processing breathstroke_video_frame_00115_pp_segmented.jpg...
# Processing breathstroke_video_frame_00116_pp_segmented.jpg...
# Processing breathstroke_video_frame_00117_pp_segmented.jpg...
# Processing breathstroke_video_frame_00118_pp_segmented.jpg...
# Processing breathstroke_video_frame_00119_pp_segmented.jpg...
# Processing breathstroke_video_frame_00120_pp_segmented.jpg...
# Processing breathstroke_video_frame_00121_pp_segmented.jpg...
# Processing breathstroke_video_frame_00122_pp_segmented.jpg...
# Processing breathstroke_video_frame_00123_pp_segmented.jpg...
# Processing breathstroke_video_frame_00124_pp_segmented.jpg...
# Processing breathstroke_video_frame_00125_pp_segmented.jpg...
# Processing breathstroke_video_frame_00126_pp_segmented.jpg...
# Processing breathstroke_video_frame_00127_pp_segmented.jpg...
# Processing breathstroke_video_frame_00128_pp_segmented.jpg...
# Processing breathstroke_video_frame_00129_pp_segmented.jpg...
# Processing breathstroke_video_frame_00130_pp_segmented.jpg...
# Processing breathstroke_video_frame_00131_pp_segmented.jpg...
# Processing breathstroke_video_frame_00132_pp_segmented.jpg...
# Processing breathstroke_video_frame_00133_pp_segmented.jpg...
# Processing breathstroke_video_frame_00134_pp_segmented.jpg...
# Processing breathstroke_video_frame_00135_pp_segmented.jpg...
# Processing breathstroke_video_frame_00136_pp_segmented.jpg...
# Processing breathstroke_video_frame_00137_pp_segmented.jpg...
# Processing breathstroke_video_frame_00138_pp_segmented.jpg...
# Processing breathstroke_video_frame_00139_pp_segmented.jpg...
# Processing breathstroke_video_frame_00140_pp_segmented.jpg...
# Processing breathstroke_video_frame_00141_pp_segmented.jpg...
# Processing breathstroke_video_frame_00142_pp_segmented.jpg...
# Processing breathstroke_video_frame_00144_pp_segmented.jpg...
# Processing breathstroke_video_frame_00145_pp_segmented.jpg...
# Processing breathstroke_video_frame_00148_pp_segmented.jpg...
# Processing breathstroke_video_frame_00149_pp_segmented.jpg...
# Processing breathstroke_video_frame_00150_pp_segmented.jpg...
# Processing breathstroke_video_frame_00152_pp_segmented.jpg...
# Processing breathstroke_video_frame_00154_pp_segmented.jpg...
# Processing breathstroke_video_frame_00155_pp_segmented.jpg...
# Processing breathstroke_video_frame_00156_pp_segmented.jpg...
# Processing breathstroke_video_frame_00157_pp_segmented.jpg...
# Processing breathstroke_video_frame_00158_pp_segmented.jpg...
# Processing breathstroke_video_frame_00159_pp_segmented.jpg...
# Processing breathstroke_video_frame_00161_pp_segmented.jpg...
# Processing breathstroke_video_frame_00162_pp_segmented.jpg...
# Processing breathstroke_video_frame_00163_pp_segmented.jpg...
# Processing breathstroke_video_frame_00165_pp_segmented.jpg...
# Processing breathstroke_video_frame_00166_pp_segmented.jpg...
# Processing breathstroke_video_frame_00167_pp_segmented.jpg...
# Processing breathstroke_video_frame_00168_pp_segmented.jpg...
# Processing breathstroke_video_frame_00169_pp_segmented.jpg...
# Processing breathstroke_video_frame_00170_pp_segmented.jpg...
# Processing breathstroke_video_frame_00171_pp_segmented.jpg...
# Processing breathstroke_video_frame_00172_pp_segmented.jpg...
# Processing breathstroke_video_frame_00173_pp_segmented.jpg...
# Processing breathstroke_video_frame_00174_pp_segmented.jpg...
# Processing breathstroke_video_frame_00175_pp_segmented.jpg...
# Processing breathstroke_video_frame_00176_pp_segmented.jpg...
# Processing breathstroke_video_frame_00177_pp_segmented.jpg...
# Processing breathstroke_video_frame_00179_pp_segmented.jpg...
# Processing breathstroke_video_frame_00180_pp_segmented.jpg...
# Processing breathstroke_video_frame_00181_pp_segmented.jpg...
# Processing breathstroke_video_frame_00182_pp_segmented.jpg...
# Processing breathstroke_video_frame_00183_pp_segmented.jpg...
# Processing breathstroke_video_frame_00184_pp_segmented.jpg...
# Processing breathstroke_video_frame_00185_pp_segmented.jpg...
# Processing breathstroke_video_frame_00186_pp_segmented.jpg...
# Processing breathstroke_video_frame_00187_pp_segmented.jpg...
# Processing breathstroke_video_frame_00188_pp_segmented.jpg...
# Processing breathstroke_video_frame_00189_pp_segmented.jpg...
# Processing breathstroke_video_frame_00190_pp_segmented.jpg...
# Processing breathstroke_video_frame_00191_pp_segmented.jpg...
# Processing breathstroke_video_frame_00192_pp_segmented.jpg...
# Processing breathstroke_video_frame_00193_pp_segmented.jpg...
# Processing breathstroke_video_frame_00194_pp_segmented.jpg...
# Processing breathstroke_video_frame_00195_pp_segmented.jpg...
# Processing breathstroke_video_frame_00196_pp_segmented.jpg...
# Processing breathstroke_video_frame_00197_pp_segmented.jpg...
# Processing breathstroke_video_frame_00201_pp_segmented.jpg...
# Processing breathstroke_video_frame_00202_pp_segmented.jpg...
# Processing breathstroke_video_frame_00203_pp_segmented.jpg...
# Processing breathstroke_video_frame_00206_pp_segmented.jpg...
# Processing breathstroke_video_frame_00207_pp_segmented.jpg...
# Processing breathstroke_video_frame_00209_pp_segmented.jpg...
# Processing breathstroke_video_frame_00210_pp_segmented.jpg...
# Processing breathstroke_video_frame_00211_pp_segmented.jpg...
# Processing breathstroke_video_frame_00212_pp_segmented.jpg...
# Processing breathstroke_video_frame_00213_pp_segmented.jpg...
# Processing breathstroke_video_frame_00215_pp_segmented.jpg...
# Processing breathstroke_video_frame_00216_pp_segmented.jpg...
# Processing breathstroke_video_frame_00217_pp_segmented.jpg...
# Processing breathstroke_video_frame_00218_pp_segmented.jpg...
# Processing breathstroke_video_frame_00220_pp_segmented.jpg...
# Processing breathstroke_video_frame_00221_pp_segmented.jpg...
# Processing breathstroke_video_frame_00222_pp_segmented.jpg...
# Processing breathstroke_video_frame_00223_pp_segmented.jpg...
# Processing breathstroke_video_frame_00224_pp_segmented.jpg...
# Processing breathstroke_video_frame_00226_pp_segmented.jpg...
# Processing breathstroke_video_frame_00227_pp_segmented.jpg...
# Processing breathstroke_video_frame_00229_pp_segmented.jpg...
# Processing breathstroke_video_frame_00230_pp_segmented.jpg...
# Processing breathstroke_video_frame_00231_pp_segmented.jpg...
# Processing breathstroke_video_frame_00232_pp_segmented.jpg...
# Processing breathstroke_video_frame_00233_pp_segmented.jpg...
# Processing breathstroke_video_frame_00234_pp_segmented.jpg...
# Processing breathstroke_video_frame_00235_pp_segmented.jpg...
# Processing breathstroke_video_frame_00236_pp_segmented.jpg...
# Processing breathstroke_video_frame_00239_pp_segmented.jpg...
# Processing breathstroke_video_frame_00240_pp_segmented.jpg...
# Processing breathstroke_video_frame_00241_pp_segmented.jpg...
# Processing breathstroke_video_frame_00242_pp_segmented.jpg...
# Processing breathstroke_video_frame_00244_pp_segmented.jpg...
# Processing breathstroke_video_frame_00247_pp_segmented.jpg...
# Processing breathstroke_video_frame_00248_pp_segmented.jpg...
# Processing breathstroke_video_frame_00249_pp_segmented.jpg...
# Processing breathstroke_video_frame_00250_pp_segmented.jpg...
# Processing breathstroke_video_frame_00258_pp_segmented.jpg...
# Processing breathstroke_video_frame_00260_pp_segmented.jpg...
# Processing breathstroke_video_frame_00261_pp_segmented.jpg...
# Processing breathstroke_video_frame_00263_pp_segmented.jpg...
# Processing breathstroke_video_frame_00264_pp_segmented.jpg...
# Processing breathstroke_video_frame_00271_pp_segmented.jpg...
# Processing breathstroke_video_frame_00272_pp_segmented.jpg...
# Processing breathstroke_video_frame_00274_pp_segmented.jpg...
# Processing breathstroke_video_frame_00275_pp_segmented.jpg...
# Processing breathstroke_video_frame_00276_pp_segmented.jpg...
# Processing breathstroke_video_frame_00279_pp_segmented.jpg...
# Processing breathstroke_video_frame_00283_pp_segmented.jpg...
# Processing breathstroke_video_frame_00287_pp_segmented.jpg...
# Processing breathstroke_video_frame_00289_pp_segmented.jpg...
# Processing breathstroke_video_frame_00290_pp_segmented.jpg...
# Processing breathstroke_video_frame_00291_pp_segmented.jpg...
# Processing breathstroke_video_frame_00292_pp_segmented.jpg...
# Processing breathstroke_video_frame_00296_pp_segmented.jpg...
# Processing breathstroke_video_frame_00297_pp_segmented.jpg...
# Processing breathstroke_video_frame_00298_pp_segmented.jpg...
# Processing breathstroke_video_frame_00302_pp_segmented.jpg...
# Processing breathstroke_video_frame_00303_pp_segmented.jpg...
# Processing breathstroke_video_frame_00304_pp_segmented.jpg...
# Processing breathstroke_video_frame_00305_pp_segmented.jpg...
# Processing breathstroke_video_frame_00306_pp_segmented.jpg...
# Processing breathstroke_video_frame_00307_pp_segmented.jpg...
# Processing breathstroke_video_frame_00308_pp_segmented.jpg...
# Processing breathstroke_video_frame_00309_pp_segmented.jpg...
# Processing breathstroke_video_frame_00310_pp_segmented.jpg...
# Processing breathstroke_video_frame_00311_pp_segmented.jpg...
# Processing breathstroke_video_frame_00312_pp_segmented.jpg...
# Processing breathstroke_video_frame_00313_pp_segmented.jpg...
# Processing breathstroke_video_frame_00314_pp_segmented.jpg...
# Processing breathstroke_video_frame_00316_pp_segmented.jpg...
# Processing breathstroke_video_frame_00318_pp_segmented.jpg...
# Processing breathstroke_video_frame_00322_pp_segmented.jpg...
# Processing breathstroke_video_frame_00323_pp_segmented.jpg...
# Processing breathstroke_video_frame_00324_pp_segmented.jpg...
# Processing breathstroke_video_frame_00433_pp_segmented.jpg...
# Processing breathstroke_video_frame_00434_pp_segmented.jpg...
# Processing breathstroke_video_frame_00440_pp_segmented.jpg...
# Processing breathstroke_video_frame_00450_pp_segmented.jpg...
# Processing breathstroke_video_frame_00455_pp_segmented.jpg...
# Processing breathstroke_video_frame_00456_pp_segmented.jpg...
# Processing breathstroke_video_frame_00458_pp_segmented.jpg...
# Processing breathstroke_video_frame_00461_pp_segmented.jpg...
# Processing breathstroke_video_frame_00462_pp_segmented.jpg...
# Processing breathstroke_video_frame_00463_pp_segmented.jpg...
# Processing breathstroke_video_frame_00465_pp_segmented.jpg...
# Processing breathstroke_video_frame_00466_pp_segmented.jpg...
# Processing breathstroke_video_frame_00472_pp_segmented.jpg...
# Processing breathstroke_video_frame_00480_pp_segmented.jpg...
# Processing breathstroke_video_frame_00486_pp_segmented.jpg...
# Processing breathstroke_video_frame_00487_pp_segmented.jpg...
# Processing breathstroke_video_frame_00488_pp_segmented.jpg...
# Processing breathstroke_video_frame_00489_pp_segmented.jpg...
# Processing breathstroke_video_frame_00490_pp_segmented.jpg...
# Processing breathstroke_video_frame_00491_pp_segmented.jpg...
# Processing breathstroke_video_frame_00492_pp_segmented.jpg...
# Processing breathstroke_video_frame_00493_pp_segmented.jpg...
# Processing breathstroke_video_frame_00494_pp_segmented.jpg...
# Processing breathstroke_video_frame_00495_pp_segmented.jpg...
# Processing breathstroke_video_frame_00496_pp_segmented.jpg...
# Processing breathstroke_video_frame_00497_pp_segmented.jpg...
# Processing breathstroke_video_frame_00498_pp_segmented.jpg...
# Processing breathstroke_video_frame_00499_pp_segmented.jpg...
# Processing breathstroke_video_frame_00500_pp_segmented.jpg...
# Processing breathstroke_video_frame_00501_pp_segmented.jpg...
# Processing breathstroke_video_frame_00502_pp_segmented.jpg...
# Processing breathstroke_video_frame_00503_pp_segmented.jpg...
# Processing breathstroke_video_frame_00504_pp_segmented.jpg...
# Processing breathstroke_video_frame_00505_pp_segmented.jpg...
# Processing breathstroke_video_frame_00506_pp_segmented.jpg...
# Processing breathstroke_video_frame_00507_pp_segmented.jpg...
# Processing breathstroke_video_frame_00508_pp_segmented.jpg...
# Processing breathstroke_video_frame_00509_pp_segmented.jpg...
# Processing breathstroke_video_frame_00510_pp_segmented.jpg...
# Processing breathstroke_video_frame_00511_pp_segmented.jpg...
# Processing breathstroke_video_frame_00512_pp_segmented.jpg...
# Processing breathstroke_video_frame_00513_pp_segmented.jpg...
# Processing breathstroke_video_frame_00514_pp_segmented.jpg...
# Processing breathstroke_video_frame_00515_pp_segmented.jpg...
# Processing breathstroke_video_frame_00516_pp_segmented.jpg...
# Processing breathstroke_video_frame_00517_pp_segmented.jpg...
# Processing breathstroke_video_frame_00518_pp_segmented.jpg...
# Processing breathstroke_video_frame_00519_pp_segmented.jpg...
# Processing breathstroke_video_frame_00520_pp_segmented.jpg...
# Processing breathstroke_video_frame_00521_pp_segmented.jpg...
# Processing breathstroke_video_frame_00522_pp_segmented.jpg...
# Processing breathstroke_video_frame_00523_pp_segmented.jpg...
# Processing breathstroke_video_frame_00524_pp_segmented.jpg...
# Processing breathstroke_video_frame_00525_pp_segmented.jpg...
# Processing breathstroke_video_frame_00527_pp_segmented.jpg...
# Processing breathstroke_video_frame_00528_pp_segmented.jpg...
# Processing breathstroke_video_frame_00529_pp_segmented.jpg...
# Processing breathstroke_video_frame_00530_pp_segmented.jpg...
# Processing breathstroke_video_frame_00531_pp_segmented.jpg...
# Processing breathstroke_video_frame_00533_pp_segmented.jpg...
# Processing breathstroke_video_frame_00534_pp_segmented.jpg...
# Processing breathstroke_video_frame_00535_pp_segmented.jpg...
# Processing breathstroke_video_frame_00536_pp_segmented.jpg...
# Processing breathstroke_video_frame_00537_pp_segmented.jpg...
# Processing breathstroke_video_frame_00538_pp_segmented.jpg...
# Processing breathstroke_video_frame_00539_pp_segmented.jpg...
# Processing breathstroke_video_frame_00540_pp_segmented.jpg...
# Processing breathstroke_video_frame_00541_pp_segmented.jpg...
# Processing breathstroke_video_frame_00543_pp_segmented.jpg...
# Processing breathstroke_video_frame_00544_pp_segmented.jpg...
# Processing breathstroke_video_frame_00545_pp_segmented.jpg...
# Processing breathstroke_video_frame_00546_pp_segmented.jpg...
# Processing breathstroke_video_frame_00547_pp_segmented.jpg...
# Processing breathstroke_video_frame_00548_pp_segmented.jpg...
# Processing breathstroke_video_frame_00549_pp_segmented.jpg...
# Processing breathstroke_video_frame_00550_pp_segmented.jpg...
# Processing breathstroke_video_frame_00551_pp_segmented.jpg...
# Processing breathstroke_video_frame_00552_pp_segmented.jpg...
# Processing breathstroke_video_frame_00553_pp_segmented.jpg...
# Processing breathstroke_video_frame_00554_pp_segmented.jpg...
# Processing breathstroke_video_frame_00555_pp_segmented.jpg...
# Processing breathstroke_video_frame_00556_pp_segmented.jpg...
# Processing breathstroke_video_frame_00557_pp_segmented.jpg...
# Processing breathstroke_video_frame_00558_pp_segmented.jpg...
# Processing breathstroke_video_frame_00559_pp_segmented.jpg...
# Processing breathstroke_video_frame_00560_pp_segmented.jpg...
# Processing breathstroke_video_frame_00561_pp_segmented.jpg...
# Processing breathstroke_video_frame_00562_pp_segmented.jpg...
# Processing breathstroke_video_frame_00563_pp_segmented.jpg...
# Processing breathstroke_video_frame_00564_pp_segmented.jpg...
# Processing breathstroke_video_frame_00565_pp_segmented.jpg...
# Processing breathstroke_video_frame_00566_pp_segmented.jpg...
# Processing breathstroke_video_frame_00567_pp_segmented.jpg...
# Processing breathstroke_video_frame_00568_pp_segmented.jpg...
# Processing breathstroke_video_frame_00569_pp_segmented.jpg...
# Processing breathstroke_video_frame_00570_pp_segmented.jpg...
# Processing breathstroke_video_frame_00571_pp_segmented.jpg...
# Processing breathstroke_video_frame_00572_pp_segmented.jpg...
# Processing breathstroke_video_frame_00573_pp_segmented.jpg...
# Processing breathstroke_video_frame_00574_pp_segmented.jpg...
# Processing breathstroke_video_frame_00575_pp_segmented.jpg...
# Processing breathstroke_video_frame_00576_pp_segmented.jpg...
# Processing breathstroke_video_frame_00577_pp_segmented.jpg...
# Processing breathstroke_video_frame_00578_pp_segmented.jpg...
# Processing breathstroke_video_frame_00579_pp_segmented.jpg...
# Processing breathstroke_video_frame_00580_pp_segmented.jpg...
# Processing breathstroke_video_frame_00581_pp_segmented.jpg...
# Processing breathstroke_video_frame_00582_pp_segmented.jpg...
# Processing breathstroke_video_frame_00583_pp_segmented.jpg...
# Processing breathstroke_video_frame_00584_pp_segmented.jpg...
# Processing breathstroke_video_frame_00585_pp_segmented.jpg...
# Processing breathstroke_video_frame_00681_pp_segmented.jpg...
# Processing breathstroke_video_frame_00682_pp_segmented.jpg...
# Processing breathstroke_video_frame_00685_pp_segmented.jpg...
# Processing breathstroke_video_frame_00686_pp_segmented.jpg...
# Processing breathstroke_video_frame_00687_pp_segmented.jpg...
# Processing breathstroke_video_frame_00692_pp_segmented.jpg...
# Processing breathstroke_video_frame_00694_pp_segmented.jpg...
# Processing breathstroke_video_frame_00695_pp_segmented.jpg...
# Processing breathstroke_video_frame_00697_pp_segmented.jpg...
# Processing breathstroke_video_frame_00698_pp_segmented.jpg...
# Processing breathstroke_video_frame_00700_pp_segmented.jpg...
# Processing breathstroke_video_frame_00704_pp_segmented.jpg...
# Processing breathstroke_video_frame_00705_pp_segmented.jpg...
# Processing breathstroke_video_frame_00708_pp_segmented.jpg...
# Processing breathstroke_video_frame_00709_pp_segmented.jpg...
# Processing breathstroke_video_frame_00711_pp_segmented.jpg...
# Processing breathstroke_video_frame_00713_pp_segmented.jpg...
# Processing breathstroke_video_frame_00714_pp_segmented.jpg...
# Processing breathstroke_video_frame_00715_pp_segmented.jpg...
# Processing breathstroke_video_frame_00716_pp_segmented.jpg...
# Processing breathstroke_video_frame_00717_pp_segmented.jpg...
# Processing breathstroke_video_frame_00718_pp_segmented.jpg...
# Processing breathstroke_video_frame_00719_pp_segmented.jpg...
# Processing breathstroke_video_frame_00720_pp_segmented.jpg...
# Processing breathstroke_video_frame_00721_pp_segmented.jpg...
# Processing breathstroke_video_frame_00722_pp_segmented.jpg...
# Processing breathstroke_video_frame_00723_pp_segmented.jpg...
# Processing breathstroke_video_frame_00724_pp_segmented.jpg...
# Processing breathstroke_video_frame_00725_pp_segmented.jpg...
# Processing breathstroke_video_frame_00726_pp_segmented.jpg...
# Processing breathstroke_video_frame_00727_pp_segmented.jpg...
# Processing breathstroke_video_frame_00728_pp_segmented.jpg...
# Processing breathstroke_video_frame_00729_pp_segmented.jpg...
# Processing breathstroke_video_frame_00730_pp_segmented.jpg...
# Processing breathstroke_video_frame_00732_pp_segmented.jpg...
# Processing breathstroke_video_frame_00733_pp_segmented.jpg...
# Processing breathstroke_video_frame_00734_pp_segmented.jpg...
# Processing breathstroke_video_frame_00735_pp_segmented.jpg...
# Processing breathstroke_video_frame_00737_pp_segmented.jpg...
# Processing breathstroke_video_frame_00738_pp_segmented.jpg...
# Processing breathstroke_video_frame_00739_pp_segmented.jpg...
# Processing breathstroke_video_frame_00740_pp_segmented.jpg...
# Processing breathstroke_video_frame_00741_pp_segmented.jpg...
# Processing breathstroke_video_frame_00742_pp_segmented.jpg...
# Processing breathstroke_video_frame_00743_pp_segmented.jpg...
# Processing breathstroke_video_frame_00744_pp_segmented.jpg...
# Processing breathstroke_video_frame_00745_pp_segmented.jpg...
# Processing breathstroke_video_frame_00746_pp_segmented.jpg...
# Processing breathstroke_video_frame_00747_pp_segmented.jpg...
# Processing breathstroke_video_frame_00748_pp_segmented.jpg...
# Processing breathstroke_video_frame_00749_pp_segmented.jpg...
# Processing breathstroke_video_frame_00750_pp_segmented.jpg...
# Processing breathstroke_video_frame_00751_pp_segmented.jpg...
# Processing breathstroke_video_frame_00752_pp_segmented.jpg...
# Processing breathstroke_video_frame_00753_pp_segmented.jpg...
# Processing breathstroke_video_frame_00754_pp_segmented.jpg...
# Processing breathstroke_video_frame_00755_pp_segmented.jpg...
# Processing breathstroke_video_frame_00756_pp_segmented.jpg...
# Processing breathstroke_video_frame_00757_pp_segmented.jpg...
# Processing breathstroke_video_frame_00758_pp_segmented.jpg...
# Processing breathstroke_video_frame_00759_pp_segmented.jpg...
# Processing breathstroke_video_frame_00760_pp_segmented.jpg...
# Processing breathstroke_video_frame_00761_pp_segmented.jpg...
# Processing breathstroke_video_frame_00762_pp_segmented.jpg...
# Processing breathstroke_video_frame_00763_pp_segmented.jpg...
# Processing breathstroke_video_frame_00764_pp_segmented.jpg...
# Processing breathstroke_video_frame_00765_pp_segmented.jpg...
# Processing breathstroke_video_frame_00766_pp_segmented.jpg...
# Processing breathstroke_video_frame_00767_pp_segmented.jpg...
# Processing breathstroke_video_frame_00768_pp_segmented.jpg...
# Processing breathstroke_video_frame_00769_pp_segmented.jpg...
# Processing breathstroke_video_frame_00770_pp_segmented.jpg...
# Processing breathstroke_video_frame_00771_pp_segmented.jpg...
# Processing breathstroke_video_frame_00772_pp_segmented.jpg...
# Processing breathstroke_video_frame_00773_pp_segmented.jpg...
# Processing breathstroke_video_frame_00774_pp_segmented.jpg...
# Processing breathstroke_video_frame_00775_pp_segmented.jpg...
# Processing breathstroke_video_frame_00776_pp_segmented.jpg...
# Processing breathstroke_video_frame_00777_pp_segmented.jpg...
# Processing breathstroke_video_frame_00778_pp_segmented.jpg...
# Processing breathstroke_video_frame_00779_pp_segmented.jpg...
# Processing breathstroke_video_frame_00780_pp_segmented.jpg...
# Processing breathstroke_video_frame_00781_pp_segmented.jpg...
# Processing breathstroke_video_frame_00782_pp_segmented.jpg...
# Processing breathstroke_video_frame_00783_pp_segmented.jpg...
# Processing breathstroke_video_frame_00784_pp_segmented.jpg...
# Processing breathstroke_video_frame_00785_pp_segmented.jpg...
# Processing breathstroke_video_frame_00786_pp_segmented.jpg...
# Processing breathstroke_video_frame_00787_pp_segmented.jpg...
# Processing breathstroke_video_frame_00788_pp_segmented.jpg...
# Processing breathstroke_video_frame_00790_pp_segmented.jpg...
# Processing breathstroke_video_frame_00791_pp_segmented.jpg...
# Processing breathstroke_video_frame_00792_pp_segmented.jpg...
# Processing breathstroke_video_frame_00793_pp_segmented.jpg...
# Processing breathstroke_video_frame_00794_pp_segmented.jpg...
# Processing breathstroke_video_frame_00795_pp_segmented.jpg...
# Processing breathstroke_video_frame_00796_pp_segmented.jpg...
# Processing breathstroke_video_frame_00797_pp_segmented.jpg...
# Processing breathstroke_video_frame_00798_pp_segmented.jpg...
# Processing breathstroke_video_frame_00799_pp_segmented.jpg...
# Processing breathstroke_video_frame_00800_pp_segmented.jpg...
# Processing breathstroke_video_frame_00801_pp_segmented.jpg...
# Processing breathstroke_video_frame_00803_pp_segmented.jpg...
# Processing breathstroke_video_frame_00804_pp_segmented.jpg...
# Processing breathstroke_video_frame_00805_pp_segmented.jpg...
# Processing breathstroke_video_frame_00806_pp_segmented.jpg...
# Processing breathstroke_video_frame_00807_pp_segmented.jpg...
# Processing breathstroke_video_frame_00808_pp_segmented.jpg...
# Processing breathstroke_video_frame_00809_pp_segmented.jpg...
# Processing breathstroke_video_frame_00810_pp_segmented.jpg...
# Processing breathstroke_video_frame_00811_pp_segmented.jpg...
# Processing breathstroke_video_frame_00812_pp_segmented.jpg...
# Processing breathstroke_video_frame_00813_pp_segmented.jpg...
# Processing breathstroke_video_frame_00814_pp_segmented.jpg...
# Processing breathstroke_video_frame_00815_pp_segmented.jpg...
# Processing breathstroke_video_frame_00816_pp_segmented.jpg...
# Processing breathstroke_video_frame_00817_pp_segmented.jpg...
# Processing breathstroke_video_frame_00819_pp_segmented.jpg...
# Processing breathstroke_video_frame_00820_pp_segmented.jpg...
# Processing breathstroke_video_frame_00821_pp_segmented.jpg...
# Processing breathstroke_video_frame_00822_pp_segmented.jpg...
# Processing breathstroke_video_frame_00823_pp_segmented.jpg...
# Processing breathstroke_video_frame_00824_pp_segmented.jpg...
# Processing breathstroke_video_frame_00828_pp_segmented.jpg...
# Processing breathstroke_video_frame_00829_pp_segmented.jpg...
# Processing breathstroke_video_frame_00830_pp_segmented.jpg...
# Processing breathstroke_video_frame_00831_pp_segmented.jpg...
# Processing breathstroke_video_frame_00832_pp_segmented.jpg...
# Processing breathstroke_video_frame_00833_pp_segmented.jpg...
# Processing breathstroke_video_frame_00834_pp_segmented.jpg...
# Processing breathstroke_video_frame_00836_pp_segmented.jpg...
# Processing breathstroke_video_frame_00891_pp_segmented.jpg...
# Processing breathstroke_video_frame_00892_pp_segmented.jpg...
# Processing breathstroke_video_frame_00893_pp_segmented.jpg...
# Processing breathstroke_video_frame_00894_pp_segmented.jpg...
# Processing breathstroke_video_frame_00895_pp_segmented.jpg...
# Processing breathstroke_video_frame_00896_pp_segmented.jpg...
# Processing breathstroke_video_frame_00897_pp_segmented.jpg...
# Processing breathstroke_video_frame_00898_pp_segmented.jpg...
# Processing breathstroke_video_frame_00899_pp_segmented.jpg...
# Processing breathstroke_video_frame_00901_pp_segmented.jpg...
# Processing breathstroke_video_frame_00902_pp_segmented.jpg...
# Processing breathstroke_video_frame_00903_pp_segmented.jpg...
# Processing breathstroke_video_frame_00904_pp_segmented.jpg...
# Processing breathstroke_video_frame_00906_pp_segmented.jpg...
# Processing breathstroke_video_frame_00907_pp_segmented.jpg...
# Processing breathstroke_video_frame_00909_pp_segmented.jpg...
# Processing breathstroke_video_frame_00910_pp_segmented.jpg...
# Processing breathstroke_video_frame_00911_pp_segmented.jpg...
# Processing breathstroke_video_frame_00912_pp_segmented.jpg...
# Processing breathstroke_video_frame_00913_pp_segmented.jpg...
# Processing breathstroke_video_frame_00914_pp_segmented.jpg...
# Processing breathstroke_video_frame_00915_pp_segmented.jpg...
# Processing breathstroke_video_frame_00916_pp_segmented.jpg...
# Processing breathstroke_video_frame_00917_pp_segmented.jpg...
# Processing breathstroke_video_frame_00918_pp_segmented.jpg...
# Processing breathstroke_video_frame_00920_pp_segmented.jpg...
# Processing breathstroke_video_frame_00922_pp_segmented.jpg...
# Processing breathstroke_video_frame_00923_pp_segmented.jpg...
# Processing breathstroke_video_frame_00924_pp_segmented.jpg...
# Processing breathstroke_video_frame_00925_pp_segmented.jpg...
# Processing breathstroke_video_frame_00926_pp_segmented.jpg...
# Processing breathstroke_video_frame_00927_pp_segmented.jpg...
# Processing breathstroke_video_frame_00929_pp_segmented.jpg...
# Processing breathstroke_video_frame_00931_pp_segmented.jpg...
# Processing breathstroke_video_frame_00932_pp_segmented.jpg...
# Processing breathstroke_video_frame_00933_pp_segmented.jpg...
# Processing breathstroke_video_frame_00935_pp_segmented.jpg...
# Processing breathstroke_video_frame_00936_pp_segmented.jpg...
# Processing breathstroke_video_frame_00937_pp_segmented.jpg...
# Processing breathstroke_video_frame_00939_pp_segmented.jpg...
# Processing breathstroke_video_frame_00940_pp_segmented.jpg...
# Processing breathstroke_video_frame_00941_pp_segmented.jpg...
# Processing breathstroke_video_frame_00942_pp_segmented.jpg...
# Processing breathstroke_video_frame_00945_pp_segmented.jpg...
# Processing breathstroke_video_frame_00946_pp_segmented.jpg...
# Processing breathstroke_video_frame_00947_pp_segmented.jpg...
# Processing breathstroke_video_frame_00948_pp_segmented.jpg...
# Processing breathstroke_video_frame_00949_pp_segmented.jpg...
# Processing breathstroke_video_frame_00950_pp_segmented.jpg...
# Processing breathstroke_video_frame_00951_pp_segmented.jpg...
# Processing breathstroke_video_frame_00952_pp_segmented.jpg...
# Processing breathstroke_video_frame_00953_pp_segmented.jpg...
# Processing breathstroke_video_frame_00954_pp_segmented.jpg...
# Processing breathstroke_video_frame_00955_pp_segmented.jpg...
# Processing breathstroke_video_frame_00956_pp_segmented.jpg...
# Processing breathstroke_video_frame_00957_pp_segmented.jpg...
# Processing breathstroke_video_frame_00958_pp_segmented.jpg...
# Processing breathstroke_video_frame_00959_pp_segmented.jpg...
# Processing breathstroke_video_frame_00960_pp_segmented.jpg...
# Processing breathstroke_video_frame_00961_pp_segmented.jpg...
# Processing breathstroke_video_frame_00962_pp_segmented.jpg...
# Processing breathstroke_video_frame_00963_pp_segmented.jpg...
# Processing breathstroke_video_frame_00964_pp_segmented.jpg...
# Processing breathstroke_video_frame_00965_pp_segmented.jpg...
# Processing breathstroke_video_frame_00966_pp_segmented.jpg...
# Processing breathstroke_video_frame_00967_pp_segmented.jpg...
# Processing breathstroke_video_frame_00968_pp_segmented.jpg...
# Processing breathstroke_video_frame_00969_pp_segmented.jpg...
# Processing breathstroke_video_frame_00970_pp_segmented.jpg...
# Processing breathstroke_video_frame_00971_pp_segmented.jpg...
# Processing breathstroke_video_frame_00972_pp_segmented.jpg...
# Processing breathstroke_video_frame_00973_pp_segmented.jpg...
# Processing breathstroke_video_frame_00974_pp_segmented.jpg...
# Processing breathstroke_video_frame_00975_pp_segmented.jpg...
# Processing breathstroke_video_frame_00976_pp_segmented.jpg...
# Processing breathstroke_video_frame_00977_pp_segmented.jpg...
# Processing breathstroke_video_frame_00978_pp_segmented.jpg...
# Processing breathstroke_video_frame_00979_pp_segmented.jpg...
# Processing breathstroke_video_frame_00983_pp_segmented.jpg...
# Processing breathstroke_video_frame_00985_pp_segmented.jpg...
# Processing breathstroke_video_frame_00986_pp_segmented.jpg...
# Processing breathstroke_video_frame_00987_pp_segmented.jpg...
# Processing breathstroke_video_frame_00988_pp_segmented.jpg...
# Processing breathstroke_video_frame_00989_pp_segmented.jpg...
# Processing breathstroke_video_frame_00990_pp_segmented.jpg...
# Processing breathstroke_video_frame_00991_pp_segmented.jpg...
# Processing breathstroke_video_frame_00992_pp_segmented.jpg...
# Processing breathstroke_video_frame_00993_pp_segmented.jpg...
# Processing breathstroke_video_frame_00994_pp_segmented.jpg...
# Processing breathstroke_video_frame_00995_pp_segmented.jpg...
# Processing breathstroke_video_frame_01000_pp_segmented.jpg...
# Processing breathstroke_video_frame_01001_pp_segmented.jpg...
# Processing breathstroke_video_frame_01002_pp_segmented.jpg...
# Processing breathstroke_video_frame_01003_pp_segmented.jpg...
# Processing breathstroke_video_frame_01004_pp_segmented.jpg...
# Processing breathstroke_video_frame_01005_pp_segmented.jpg...
# Processing breathstroke_video_frame_01006_pp_segmented.jpg...
# Processing breathstroke_video_frame_01007_pp_segmented.jpg...
# Processing breathstroke_video_frame_01009_pp_segmented.jpg...
# Processing breathstroke_video_frame_01011_pp_segmented.jpg...
# Processing breathstroke_video_frame_01012_pp_segmented.jpg...
# Processing breathstroke_video_frame_01014_pp_segmented.jpg...
# Processing breathstroke_video_frame_01015_pp_segmented.jpg...
# Processing breathstroke_video_frame_01016_pp_segmented.jpg...
# Processing breathstroke_video_frame_01017_pp_segmented.jpg...
# Processing breathstroke_video_frame_01018_pp_segmented.jpg...
# Processing breathstroke_video_frame_01019_pp_segmented.jpg...
# Processing breathstroke_video_frame_01020_pp_segmented.jpg...
# Processing breathstroke_video_frame_01021_pp_segmented.jpg...
# Processing breathstroke_video_frame_01022_pp_segmented.jpg...
# Processing breathstroke_video_frame_01024_pp_segmented.jpg...
# Processing breathstroke_video_frame_01025_pp_segmented.jpg...
# Processing breathstroke_video_frame_01026_pp_segmented.jpg...
# Processing breathstroke_video_frame_01027_pp_segmented.jpg...
# Processing breathstroke_video_frame_01028_pp_segmented.jpg...
# Processing breathstroke_video_frame_01029_pp_segmented.jpg...
# Processing breathstroke_video_frame_01030_pp_segmented.jpg...
# Processing breathstroke_video_frame_01031_pp_segmented.jpg...
# Processing breathstroke_video_frame_01032_pp_segmented.jpg...
# Processing breathstroke_video_frame_01033_pp_segmented.jpg...
# Processing breathstroke_video_frame_01041_pp_segmented.jpg...
# Processing breathstroke_video_frame_01043_pp_segmented.jpg...
# Processing breathstroke_video_frame_01046_pp_segmented.jpg...
# Processing breathstroke_video_frame_01049_pp_segmented.jpg...
# Processing breathstroke_video_frame_01052_pp_segmented.jpg...
# Processing breathstroke_video_frame_01055_pp_segmented.jpg...
# Processing breathstroke_video_frame_01056_pp_segmented.jpg...
# Processing breathstroke_video_frame_01057_pp_segmented.jpg...
# Processing breathstroke_video_frame_01059_pp_segmented.jpg...
# Processing breathstroke_video_frame_01061_pp_segmented.jpg...
# Processing breathstroke_video_frame_01067_pp_segmented.jpg...
# Processing breathstroke_video_frame_01105_pp_segmented.jpg...
# Processing breathstroke_video_frame_01107_pp_segmented.jpg...
# Processing breathstroke_video_frame_01109_pp_segmented.jpg...
# Processing breathstroke_video_frame_01110_pp_segmented.jpg...
# Processing breathstroke_video_frame_01116_pp_segmented.jpg...
# Processing breathstroke_video_frame_01117_pp_segmented.jpg...
# Processing breathstroke_video_frame_01118_pp_segmented.jpg...
# Processing breathstroke_video_frame_01119_pp_segmented.jpg...
# Processing breathstroke_video_frame_01120_pp_segmented.jpg...
# Processing breathstroke_video_frame_01124_pp_segmented.jpg...
# Processing breathstroke_video_frame_01128_pp_segmented.jpg...
# Processing breathstroke_video_frame_01130_pp_segmented.jpg...
# Processing breathstroke_video_frame_01131_pp_segmented.jpg...
# Processing breathstroke_video_frame_01133_pp_segmented.jpg...
# Processing breathstroke_video_frame_01135_pp_segmented.jpg...
# Processing breathstroke_video_frame_01136_pp_segmented.jpg...
# Processing breathstroke_video_frame_01137_pp_segmented.jpg...
# Processing breathstroke_video_frame_01139_pp_segmented.jpg...
# Processing breathstroke_video_frame_01144_pp_segmented.jpg...
# Processing breathstroke_video_frame_01145_pp_segmented.jpg...
# Processing breathstroke_video_frame_01146_pp_segmented.jpg...
# Processing breathstroke_video_frame_01147_pp_segmented.jpg...
# Processing breathstroke_video_frame_01148_pp_segmented.jpg...
# Processing breathstroke_video_frame_01149_pp_segmented.jpg...
# Processing breathstroke_video_frame_01151_pp_segmented.jpg...
# Processing breathstroke_video_frame_01152_pp_segmented.jpg...
# Processing breathstroke_video_frame_01153_pp_segmented.jpg...
# Processing breathstroke_video_frame_01154_pp_segmented.jpg...
# Processing breathstroke_video_frame_01155_pp_segmented.jpg...
# Processing breathstroke_video_frame_01160_pp_segmented.jpg...
# Processing breathstroke_video_frame_01162_pp_segmented.jpg...
# Processing breathstroke_video_frame_01169_pp_segmented.jpg...
# Processing breathstroke_video_frame_01170_pp_segmented.jpg...
# Processing breathstroke_video_frame_01171_pp_segmented.jpg...
# Processing breathstroke_video_frame_01172_pp_segmented.jpg...
# Processing breathstroke_video_frame_01174_pp_segmented.jpg...
# Processing breathstroke_video_frame_01175_pp_segmented.jpg...
# Processing breathstroke_video_frame_01176_pp_segmented.jpg...
# Processing breathstroke_video_frame_01177_pp_segmented.jpg...
# Processing breathstroke_video_frame_01178_pp_segmented.jpg...
# Processing breathstroke_video_frame_01179_pp_segmented.jpg...
# Processing breathstroke_video_frame_01180_pp_segmented.jpg...
# Processing breathstroke_video_frame_01181_pp_segmented.jpg...
# Processing breathstroke_video_frame_01184_pp_segmented.jpg...
# Processing breathstroke_video_frame_01185_pp_segmented.jpg...
# Processing breathstroke_video_frame_01188_pp_segmented.jpg...
# Processing breathstroke_video_frame_01192_pp_segmented.jpg...
# Processing breathstroke_video_frame_01193_pp_segmented.jpg...
# Processing breathstroke_video_frame_01194_pp_segmented.jpg...
# Processing breathstroke_video_frame_01195_pp_segmented.jpg...
# Processing breathstroke_video_frame_01196_pp_segmented.jpg...
# Processing breathstroke_video_frame_01197_pp_segmented.jpg...
# Processing breathstroke_video_frame_01198_pp_segmented.jpg...
# Processing breathstroke_video_frame_01199_pp_segmented.jpg...
# Processing breathstroke_video_frame_01200_pp_segmented.jpg...
# Processing breathstroke_video_frame_01201_pp_segmented.jpg...
# Processing breathstroke_video_frame_01202_pp_segmented.jpg...
# Processing breathstroke_video_frame_01203_pp_segmented.jpg...
# Processing breathstroke_video_frame_01205_pp_segmented.jpg...
# Processing breathstroke_video_frame_01206_pp_segmented.jpg...
# Processing breathstroke_video_frame_01208_pp_segmented.jpg...
# Processing breathstroke_video_frame_01210_pp_segmented.jpg...
# Processing breathstroke_video_frame_01211_pp_segmented.jpg...
# Processing breathstroke_video_frame_01212_pp_segmented.jpg...
# Processing breathstroke_video_frame_01213_pp_segmented.jpg...
# Processing breathstroke_video_frame_01215_pp_segmented.jpg...
# Processing breathstroke_video_frame_01216_pp_segmented.jpg...
# Processing breathstroke_video_frame_01217_pp_segmented.jpg...
# Processing breathstroke_video_frame_01218_pp_segmented.jpg...
# Processing breathstroke_video_frame_01219_pp_segmented.jpg...
# Processing breathstroke_video_frame_01220_pp_segmented.jpg...
# Processing breathstroke_video_frame_01221_pp_segmented.jpg...
# Processing breathstroke_video_frame_01222_pp_segmented.jpg...
# Processing breathstroke_video_frame_01223_pp_segmented.jpg...
# Processing breathstroke_video_frame_01224_pp_segmented.jpg...
# Processing breathstroke_video_frame_01225_pp_segmented.jpg...
# Processing breathstroke_video_frame_01226_pp_segmented.jpg...
# Processing breathstroke_video_frame_01227_pp_segmented.jpg...
# Processing breathstroke_video_frame_01228_pp_segmented.jpg...
# Processing breathstroke_video_frame_01229_pp_segmented.jpg...
# Processing breathstroke_video_frame_01230_pp_segmented.jpg...
# Processing breathstroke_video_frame_01231_pp_segmented.jpg...
# Processing breathstroke_video_frame_01232_pp_segmented.jpg...
# Processing breathstroke_video_frame_01233_pp_segmented.jpg...
# Processing breathstroke_video_frame_01234_pp_segmented.jpg...
# Processing breathstroke_video_frame_01235_pp_segmented.jpg...
# Processing breathstroke_video_frame_01236_pp_segmented.jpg...
# Processing breathstroke_video_frame_01237_pp_segmented.jpg...
# Processing breathstroke_video_frame_01241_pp_segmented.jpg...
# Processing breathstroke_video_frame_01244_pp_segmented.jpg...
# Processing breathstroke_video_frame_01245_pp_segmented.jpg...
# Processing breathstroke_video_frame_01246_pp_segmented.jpg...
# Processing breathstroke_video_frame_01247_pp_segmented.jpg...
# Processing breathstroke_video_frame_01248_pp_segmented.jpg...
# Processing breathstroke_video_frame_01249_pp_segmented.jpg...
# Processing breathstroke_video_frame_01250_pp_segmented.jpg...
# Processing breathstroke_video_frame_01251_pp_segmented.jpg...
# Processing breathstroke_video_frame_01252_pp_segmented.jpg...
# Processing breathstroke_video_frame_01253_pp_segmented.jpg...
# Processing breathstroke_video_frame_01254_pp_segmented.jpg...
# Processing breathstroke_video_frame_01255_pp_segmented.jpg...
# Processing breathstroke_video_frame_01256_pp_segmented.jpg...
# Processing breathstroke_video_frame_01257_pp_segmented.jpg...
# Processing breathstroke_video_frame_01258_pp_segmented.jpg...
# Processing breathstroke_video_frame_01259_pp_segmented.jpg...
# Processing breathstroke_video_frame_01260_pp_segmented.jpg...
# Processing breathstroke_video_frame_01261_pp_segmented.jpg...
# Processing breathstroke_video_frame_01262_pp_segmented.jpg...
# Processing breathstroke_video_frame_01263_pp_segmented.jpg...
# Processing breathstroke_video_frame_01264_pp_segmented.jpg...
# Processing breathstroke_video_frame_01265_pp_segmented.jpg...
# Processing breathstroke_video_frame_01266_pp_segmented.jpg...
# Processing breathstroke_video_frame_01267_pp_segmented.jpg...
# Processing breathstroke_video_frame_01268_pp_segmented.jpg...
# Processing breathstroke_video_frame_01269_pp_segmented.jpg...
# Processing breathstroke_video_frame_01270_pp_segmented.jpg...
# Processing breathstroke_video_frame_01271_pp_segmented.jpg...
# Processing breathstroke_video_frame_01272_pp_segmented.jpg...
# Processing breathstroke_video_frame_01273_pp_segmented.jpg...
# Processing breathstroke_video_frame_01274_pp_segmented.jpg...
# Processing breathstroke_video_frame_01275_pp_segmented.jpg...
# Processing breathstroke_video_frame_01276_pp_segmented.jpg...
# Processing breathstroke_video_frame_01277_pp_segmented.jpg...
# Processing breathstroke_video_frame_01278_pp_segmented.jpg...
# Processing breathstroke_video_frame_01279_pp_segmented.jpg...
# Processing breathstroke_video_frame_01280_pp_segmented.jpg...
# Processing breathstroke_video_frame_01281_pp_segmented.jpg...
# Processing breathstroke_video_frame_01282_pp_segmented.jpg...
# Processing breathstroke_video_frame_01283_pp_segmented.jpg...
# Processing breathstroke_video_frame_01284_pp_segmented.jpg...
# Processing breathstroke_video_frame_01285_pp_segmented.jpg...
# Processing breathstroke_video_frame_01286_pp_segmented.jpg...
# Processing breathstroke_video_frame_01287_pp_segmented.jpg...
# Processing breathstroke_video_frame_01288_pp_segmented.jpg...
# Processing breathstroke_video_frame_01289_pp_segmented.jpg...
# Processing breathstroke_video_frame_01290_pp_segmented.jpg...
# Processing breathstroke_video_frame_01291_pp_segmented.jpg...
# Processing breathstroke_video_frame_01292_pp_segmented.jpg...
# Processing breathstroke_video_frame_01293_pp_segmented.jpg...
# Processing breathstroke_video_frame_01294_pp_segmented.jpg...
# Processing breathstroke_video_frame_01296_pp_segmented.jpg...
# Processing breathstroke_video_frame_01297_pp_segmented.jpg...
# Processing breathstroke_video_frame_01298_pp_segmented.jpg...
# Processing breathstroke_video_frame_01299_pp_segmented.jpg...
# Processing breathstroke_video_frame_01300_pp_segmented.jpg...
# Processing breathstroke_video_frame_01302_pp_segmented.jpg...
# Processing breathstroke_video_frame_01303_pp_segmented.jpg...
# Processing breathstroke_video_frame_01304_pp_segmented.jpg...
# Processing breathstroke_video_frame_01309_pp_segmented.jpg...
# Processing breathstroke_video_frame_01327_pp_segmented.jpg...
# Processing breathstroke_video_frame_01328_pp_segmented.jpg...
# Processing breathstroke_video_frame_01374_pp_segmented.jpg...
# Processing breathstroke_video_frame_01376_pp_segmented.jpg...
# Processing breathstroke_video_frame_01379_pp_segmented.jpg...
# Processing breathstroke_video_frame_01381_pp_segmented.jpg...
# Processing breathstroke_video_frame_01390_pp_segmented.jpg...
# Processing breathstroke_video_frame_01394_pp_segmented.jpg...
# Processing breathstroke_video_frame_01395_pp_segmented.jpg...
# Processing breathstroke_video_frame_01400_pp_segmented.jpg...
# Processing breathstroke_video_frame_01406_pp_segmented.jpg...
# Processing breathstroke_video_frame_01409_pp_segmented.jpg...
# Processing breathstroke_video_frame_01411_pp_segmented.jpg...
# Processing breathstroke_video_frame_01416_pp_segmented.jpg...
# Processing breathstroke_video_frame_01417_pp_segmented.jpg...
# Processing breathstroke_video_frame_01418_pp_segmented.jpg...
# Processing breathstroke_video_frame_01419_pp_segmented.jpg...
# Processing breathstroke_video_frame_01420_pp_segmented.jpg...
# Processing breathstroke_video_frame_01421_pp_segmented.jpg...
# Processing breathstroke_video_frame_01422_pp_segmented.jpg...
# Processing breathstroke_video_frame_01423_pp_segmented.jpg...
# Processing breathstroke_video_frame_01424_pp_segmented.jpg...
# Processing breathstroke_video_frame_01425_pp_segmented.jpg...
# Processing breathstroke_video_frame_01427_pp_segmented.jpg...
# Processing breathstroke_video_frame_01428_pp_segmented.jpg...
# Processing breathstroke_video_frame_01429_pp_segmented.jpg...
# Processing breathstroke_video_frame_01430_pp_segmented.jpg...
# Processing breathstroke_video_frame_01431_pp_segmented.jpg...
# Processing breathstroke_video_frame_01432_pp_segmented.jpg...
# Processing breathstroke_video_frame_01433_pp_segmented.jpg...
# Processing breathstroke_video_frame_01434_pp_segmented.jpg...
# Processing breathstroke_video_frame_01435_pp_segmented.jpg...
# Processing breathstroke_video_frame_01436_pp_segmented.jpg...
# Processing breathstroke_video_frame_01437_pp_segmented.jpg...
# Processing breathstroke_video_frame_01438_pp_segmented.jpg...
# Processing breathstroke_video_frame_01439_pp_segmented.jpg...
# Processing breathstroke_video_frame_01440_pp_segmented.jpg...
# Processing breathstroke_video_frame_01441_pp_segmented.jpg...
# Processing breathstroke_video_frame_01442_pp_segmented.jpg...
# Processing breathstroke_video_frame_01443_pp_segmented.jpg...
# Processing breathstroke_video_frame_01444_pp_segmented.jpg...
# Processing breathstroke_video_frame_01445_pp_segmented.jpg...
# Processing breathstroke_video_frame_01447_pp_segmented.jpg...
# Processing breathstroke_video_frame_01448_pp_segmented.jpg...
# Processing breathstroke_video_frame_01449_pp_segmented.jpg...
# Processing breathstroke_video_frame_01450_pp_segmented.jpg...
# Processing breathstroke_video_frame_01451_pp_segmented.jpg...
# Processing breathstroke_video_frame_01452_pp_segmented.jpg...
# Processing breathstroke_video_frame_01453_pp_segmented.jpg...
# Processing breathstroke_video_frame_01455_pp_segmented.jpg...
# Processing breathstroke_video_frame_01456_pp_segmented.jpg...
# Processing breathstroke_video_frame_01457_pp_segmented.jpg...
# Processing breathstroke_video_frame_01459_pp_segmented.jpg...
# Processing breathstroke_video_frame_01460_pp_segmented.jpg...
# Processing breathstroke_video_frame_01461_pp_segmented.jpg...
# Processing breathstroke_video_frame_01462_pp_segmented.jpg...
# Processing breathstroke_video_frame_01463_pp_segmented.jpg...
# Processing breathstroke_video_frame_01465_pp_segmented.jpg...
# Processing breathstroke_video_frame_01466_pp_segmented.jpg...
# Processing breathstroke_video_frame_01467_pp_segmented.jpg...
# Processing breathstroke_video_frame_01468_pp_segmented.jpg...
# Processing breathstroke_video_frame_01469_pp_segmented.jpg...
# Processing breathstroke_video_frame_01470_pp_segmented.jpg...
# Processing breathstroke_video_frame_01472_pp_segmented.jpg...
# Processing breathstroke_video_frame_01473_pp_segmented.jpg...
# Processing breathstroke_video_frame_01474_pp_segmented.jpg...
# Processing breathstroke_video_frame_01475_pp_segmented.jpg...
# Processing breathstroke_video_frame_01476_pp_segmented.jpg...
# Processing breathstroke_video_frame_01477_pp_segmented.jpg...
# Processing breathstroke_video_frame_01478_pp_segmented.jpg...
# Processing breathstroke_video_frame_01479_pp_segmented.jpg...
# Processing breathstroke_video_frame_01482_pp_segmented.jpg...
# Processing breathstroke_video_frame_01483_pp_segmented.jpg...
# Processing breathstroke_video_frame_01485_pp_segmented.jpg...
# Processing breathstroke_video_frame_01486_pp_segmented.jpg...
# Processing breathstroke_video_frame_01488_pp_segmented.jpg...
# Processing breathstroke_video_frame_01489_pp_segmented.jpg...
# Processing breathstroke_video_frame_01490_pp_segmented.jpg...
# Processing breathstroke_video_frame_01491_pp_segmented.jpg...
# Processing breathstroke_video_frame_01502_pp_segmented.jpg...
# Processing complete. Processed images saved to: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\POSE\breathstroke_POSE
