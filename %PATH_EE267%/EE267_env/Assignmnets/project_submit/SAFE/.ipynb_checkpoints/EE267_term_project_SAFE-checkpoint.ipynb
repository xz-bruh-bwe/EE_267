# %% [markdown]
# ### Project Part 1: Extract swimmers photos from swimmers video.
#     This kernel is associated with converting the swimmers video and then saving it to a specific file location

# %%
### Imports
import cv2
import os
import shutil

# %%
# %pwd
# Out:
# 'C:\\Users\\Baron\\Desktop\\EE_267_Repo\\EE_267\\%PATH_EE267%\\EE267_env\\Assignmnets\\project_submit'

# %%
### Designated File Location
backstroke_video_location = "C:\\Users\\Baron\\Documents\\Grad_School\\EE_267\\term_project\\videos\\backstroke_video.mp4"
breathstroke_video_location = "C:\\Users\\Baron\\Documents\\Grad_School\\EE_267\\term_project\\videos\\breathstroke_video.mp4"
butterfly_video_location = "C:\\Users\\Baron\\Documents\\Grad_School\\EE_267\\term_project\\videos\\buttefly_video.mp4"

backstroke_pictures_location_raw = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\backstroke_pictures_raw" 
breathstroke_pictures_location_raw = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\breathstroke_pictures_raw" 
butterfly_pictures_location_raw = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\butterfly_pictures_raw"

# %%
### Extract frames function
def extract_frames(video_path, output_folder):
    # Extract the video file name without extension to use as a prefix
    video_name = os.path.splitext(os.path.basename(video_path))[0]

    # Check if the output folder exists, and if so, clear it
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)  # Remove all existing files in the folder
    os.makedirs(output_folder)  # Re-create the empty folder

    # Open the video file
    video_capture = cv2.VideoCapture(video_path)
    
    # Check if the video was opened successfully
    if not video_capture.isOpened():
        print("Error: Could not open video.")
        return

    frame_count = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_rate = int(video_capture.get(cv2.CAP_PROP_FPS))
    print(f"Total frames: {frame_count}, Frame rate: {frame_rate} fps")

    # Extract and save frames
    frame_index = 0
    while True:
        ret, frame = video_capture.read()
        if not ret:
            break
        
        # Define the filename for each frame with the video name as a prefix
        frame_filename = os.path.join(output_folder, f"{video_name}_frame_{frame_index:05d}.jpg")
        
        # Write the frame to the output folder
        cv2.imwrite(frame_filename, frame)
        
        print(f"Extracted frame {frame_index}")
        frame_index += 1

    # Release the video capture object
    video_capture.release()
    print(f"Frames saved to {output_folder}")

# %% [markdown]
# ### Run Function
# #extract_frames(video_path, output_folder)
# #-----------------------------------------
# #extract_frames(backstroke_video_location, backstroke_pictures_location_raw)
# #extract_frames(breathstroke_video_location, breathstroke_pictures_location_raw)
# #extract_frames(butterfly_video_location, butterfly_pictures_location_raw)

# %% [markdown]
# ### Project Part 2: Run the newly created pictures through an object detection model, and then a segnment anything
#     These kernels are associated with applying the segment anything model (SAM) to extract the swimmers from the background.
#     First the code needs to located the swimmers, and then segment them.

# %%
import cv2
import numpy as np
from PIL import Image

# Load the MobileNet SSD model
prototxt = r"C:\Users\Baron\Desktop\MobileNet-SSD\\deploy.prototxt"
caffemodel = r"C:\Users\Baron\Desktop\MobileNet-SSD\\mobilenet_iter_73000.caffemodel"

# %%
#===========================================
""" 
This is a comment Block
"""
#===========================================
def preprocess_image(image):
    # Convert image to YUV color space
    image_yuv = cv2.cvtColor(image, cv2.COLOR_BGR2YUV)
    # Apply histogram equalization on the Y channel (luminance)
    image_yuv[:, :, 0] = cv2.equalizeHist(image_yuv[:, :, 0])
    # Convert back to BGR color space
    processed_image = cv2.cvtColor(image_yuv, cv2.COLOR_YUV2BGR)
    return processed_image

def gamma_correction(image, gamma=2):
    # Build a lookup table mapping pixel values [0, 255] to adjusted gamma values
    inv_gamma = 1.0 / gamma
    table = np.array([(i / 255.0) ** inv_gamma * 255 for i in np.arange(256)]).astype("uint8")
    # Apply gamma correction
    gamma_corrected_image = cv2.LUT(image, table)
    
    # Show the image after gamma correction
    ##cv2.imshow("Gamma Corrected Image", gamma_corrected_image)
    ##print("Showing Gamma Corrected Image...")
    ##cv2.waitKey(0)  # Wait for a key press
    ##cv2.destroyAllWindows()
    return gamma_corrected_image

def crop_image(image):
    """
    Crops the image to its center, reducing dimensions by half.
    Parameters:
    - image: Input image (NumPy array).
    Returns:
    - Cropped image.
    """
    # Get current dimensions
    height, width = image.shape[:2]
    print(f"Original size: {width}x{height}")

    # Calculate cropping box (center crop)
    crop_width = width // 2
    crop_height = height // 2

    start_x = (width - crop_width) // 2
    start_y = (height - crop_height) // 2
    end_x = start_x + crop_width
    end_y = start_y + crop_height

    # Perform the crop
    cropped_image = image[start_y:end_y, start_x:end_x]
    print(f"Cropped image size: {crop_width}x{crop_height}")
    return cropped_image
    
def sharpen_image(image):
    # Define a sharpening kernel
    sharpening_kernel = np.array([[0, -1, 0],
                                   [-1, 5, -1],
                                   [0, -1, 0]])
    # Apply the sharpening kernel to the image
    sharpened_image = cv2.filter2D(image, -1, sharpening_kernel)
    return sharpened_image


def apply_median_filter(image, kernel_size=5):
    if kernel_size % 2 == 0:
        raise ValueError("Kernel size must be an odd number!")

    # Apply the median filter
    filtered_image = cv2.medianBlur(image, kernel_size)
    return filtered_image

def remove_dark_colors(image, threshold=50, replacement_color=(200, 200, 200)):
    # Load the image
    #image = cv2.imread(image_path)
    if image is None:
        print("Error: Unable to load image.")
        return None

    # Convert to grayscale to detect intensity of dark regions
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Create a mask for dark colors (pixels with intensity below the threshold)
    mask = gray < threshold

    # Replace dark pixels with the replacement color
    output_image = image.copy()
    output_image[mask] = replacement_color

    return output_image



def enhance_image(image): # Change back to image
    # Apply histogram equalization
    #image = cv2.imread(input_path)
    
    image = preprocess_image(image)
    # Apply gamma correction
    image = gamma_correction(image, gamma=3.5)
    #image = sharpen_image(image)
    #image = apply_median_filter(image)
    #image = crop_image(image)

    # Show the final enhanced image
    #cv2.imshow("Enhanced Image", image)
    #print("Showing Enhanced Image...")
    #cv2.waitKey(0)  # Wait for a key press
    #cv2.destroyAllWindows()
    return image

# %% [markdown]
# enhance_image(r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\backstroke_pictures_raw\backstroke_video_frame_00018.jpg");

# %%
# Function to process and display images one at a time
def process_and_display_images(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    
    # Check if the output folder exists, and if so, clear it
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)  # Remove all existing files in the folder
    os.makedirs(output_folder)  # Re-create the empty folder

   # Loop through all files in the input folder
    for filename in os.listdir(input_folder):
        # Construct full file path
        input_path = os.path.join(input_folder, filename)
        
        # Extract the file name and extension
        file_base, file_ext = os.path.splitext(filename)
        output_filename = f"{file_base}_pp{file_ext}"  # Add the '_pp' suffix
        output_path = os.path.join(output_folder, output_filename)

        # Check if it is a file and has an image extension
        if os.path.isfile(input_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            # Read the image
            image = cv2.imread(input_path)
            if image is not None:
                # Enhance the image
                enhanced_image = enhance_image(image)
                
                # Save the enhanced image to the output folder
                cv2.imwrite(output_path, enhanced_image)
                print(f"Processed and saved: {output_path}")
            else:
                print(f"Failed to read image: {input_path}")

# %%
# Example usage
backstroke_pictures_location_raw = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\raw\backstroke_pictures_raw" 

backstroke_pictures_location_pp = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp"

process_and_display_images(backstroke_pictures_location_raw, backstroke_pictures_location_pp)
print("finished")
# Out:
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00000_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00001_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00002_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00003_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00004_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00005_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00006_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00007_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00008_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00009_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00010_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00011_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00012_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00013_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00014_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00015_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00016_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00017_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00018_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00019_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00020_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00021_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00022_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00023_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00024_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00025_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00026_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00027_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00028_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00029_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00030_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00031_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00032_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00033_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00034_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00035_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00036_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00037_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00038_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00039_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00040_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00041_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00042_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00043_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00044_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00045_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00046_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00047_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00048_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00049_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00050_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00051_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00052_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00053_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00054_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00055_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00056_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00057_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00058_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00059_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00060_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00061_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00062_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00063_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00064_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00065_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00066_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00067_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00068_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00069_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00070_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00071_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00072_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00073_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00074_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00075_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00076_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00077_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00078_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00079_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00080_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00081_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00082_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00083_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00084_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00085_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00086_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00087_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00088_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00089_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00090_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00091_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00092_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00093_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00094_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00281_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00282_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00283_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00284_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00285_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00286_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00287_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00288_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00289_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00290_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00291_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00292_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00293_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00294_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00295_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00296_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00297_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00298_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00299_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00300_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00301_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00302_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00303_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00304_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00305_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00306_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00307_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00308_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00309_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00310_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00311_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00312_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00313_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00314_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00315_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00316_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00317_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00318_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00319_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00320_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00321_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00322_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00323_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00324_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00325_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00326_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00327_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00328_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00329_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00330_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00331_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00332_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00333_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00334_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00335_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00336_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00337_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00338_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00339_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00340_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00341_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00342_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00343_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00344_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00345_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00346_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00347_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00348_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00349_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00350_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00351_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00352_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00353_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00354_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00355_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00356_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00357_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00358_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00426_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00427_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00428_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00429_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00430_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00431_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00432_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00433_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00434_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00435_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00436_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00437_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00438_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00439_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00440_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00441_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00442_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00443_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00444_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00445_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00446_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00447_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00448_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00449_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00450_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00451_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00452_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00453_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00454_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00455_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00456_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00457_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00458_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00459_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00460_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00461_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00462_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00463_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00464_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00465_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00466_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00467_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00468_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00469_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00470_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00471_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00472_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00473_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00474_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00475_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00476_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00477_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00478_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00479_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00480_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00481_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00482_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00483_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00484_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00485_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00486_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00487_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00488_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00489_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00490_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00491_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00492_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00493_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00494_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00495_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00496_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00497_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00498_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00499_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00500_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00501_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00502_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00503_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00504_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00505_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00506_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00507_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00508_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00509_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00510_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00511_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00512_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00513_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00514_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00515_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00516_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00517_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00518_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00519_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00520_pp.jpg
# ...
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00848_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00849_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00850_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00851_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00852_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00853_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00854_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00855_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00856_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00857_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00858_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00859_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00860_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00861_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00862_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00863_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00864_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00865_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00866_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00867_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00868_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01070_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01071_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01072_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01073_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01074_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01075_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01076_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01077_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01078_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01079_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01189_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01190_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01191_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01192_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01193_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01194_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01195_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01196_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01197_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01198_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01199_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01200_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01201_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01202_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01203_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01204_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01205_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01206_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01207_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01208_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01209_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01210_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01211_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01212_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01213_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01214_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01215_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01216_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01217_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01218_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01219_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01220_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01221_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01222_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01223_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01224_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01225_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01226_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01227_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01228_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01229_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01230_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01231_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01232_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01233_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01234_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01235_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01236_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01237_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01238_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01239_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01240_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01241_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01242_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01243_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01244_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01245_pp.jpg
# Processed and saved: C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_01246_pp.jpg
# finished

# %% [markdown]
# ### COLAPSED

# %%
pip cache purge
# Out:
# Files removed: 0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: No matching packages

# %%
#pip install mediapipe==0.10.14 --user

# %%
import cv2
import mediapipe as mp
import numpy as np

# Initialize MediaPipe BlazePose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, model_complexity=2, enable_segmentation=False , min_detection_confidence=0.2, min_tracking_confidence=0.2)

def detect_swimmer_with_blazepose(image_path):
    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Failed to load image {image_path}")
        return None

    # Convert the image to RGB (MediaPipe requires RGB input)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Process the image with BlazePose
    results = pose.process(image_rgb)

    # Get image dimensions
    h, w, _ = image.shape

    # Draw grid for visualization (optional)
    grid_color = (255, 255, 255)  # White color for the grid
    num_rows, num_cols = 10, 10  # Define grid dimensions
    for row in range(1, num_rows):
        y = row * h // num_rows
        cv2.line(image, (0, y), (w, y), grid_color, 1)
    for col in range(1, num_cols):
        x = col * w // num_cols
        cv2.line(image, (x, 0), (x, h), grid_color, 1)

    pose.close()
    
    # List to store detected keypoints
    detected_points = []
    
    
    # Extract landmarks (key points) if they exist
    if results.pose_landmarks:
        for idx, landmark in enumerate(results.pose_landmarks.landmark):
            # Convert normalized coordinates to pixel coordinates
            x = int(landmark.x * w)
            y = int(landmark.y * h)
            confidence = landmark.visibility

            # Append the keypoint (x, y) to the list
            detected_points.append([x, y])

            # Visualize the keypoints on the image
            if confidence > 0.3:  # Only draw points with good visibility
                cv2.circle(image, (x, y), 5, (0, 255, 0), -1)  # Green dots for keypoints
                cv2.putText(image, str(idx), (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (0, 255, 0), 1)
    
    # Handle the case when no points are detected
    if not detected_points:
        print("No swimmer detected.")
        return None, image
    
    return np.array(detected_points), image

# Initialize MediaPipe BlazePose

# %%
# Initialize MediaPipe BlazePos
# Example usage (DELETE LATER FOR TESTING PURPOSES ONLY
detected_point, processed_image = detect_swimmer_with_blazepose(r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00001_pp.jpg")
# Display the final image
cv2.imshow("Processed Image with Grid", processed_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Initialize MediaPipe BlazePose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, model_complexity=2, enable_segmentation=False , min_detection_confidence=0.3, min_tracking_confidence=0.3)
# Out:
# No swimmer detected.

# %% [markdown]
# ### Swimmer Segmentation

# %%
import torch
from torchvision import models, transforms
import torchvision
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
from segment_anything import sam_model_registry, SamPredictor

# %%
def show_mask(mask, ax, random_color=False):
    if random_color:
        color = np.concatenate([np.random.random(3), np.array([0.6])], axis=0)
    else:
        color = np.array([30/255, 144/255, 255/255, 0.6])
    h, w = mask.shape[-2:]
    mask_image = mask.reshape(h, w, 1) * color.reshape(1, 1, -1)
    ax.imshow(mask_image)
    
def show_points(coords, labels, ax, marker_size=375):
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color='green', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color='red', marker='*', s=marker_size, edgecolor='white', linewidth=1.25)   
    
def show_box(box, ax):
    x0, y0 = box[0], box[1]
    w, h = box[2] - box[0], box[3] - box[1]
    ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor='green', facecolor=(0,0,0,0), lw=2))

# %%
def detect_and_segment_swimmer(image_path, model_checkpoint, model_type="vit_h", device="cpu"):


    # Detect swimmer using BlazePose
    detected_points, detected_image = detect_swimmer_with_blazepose(image_path)

    if detected_points is None:
        print("No swimmer detected.")
        return

    # Initialize SAM model
    sam = sam_model_registry[model_type](checkpoint=model_checkpoint)
    sam.to(device=device)
    predictor = SamPredictor(sam)

    # Set SAM's input image
    predictor.set_image(detected_image)

    # Use detected swimmer points as input for SAM
    input_point = detected_points
    input_label = np.array([1] * len(detected_points))  # Positive label for all points

    # Perform SAM prediction
    masks, scores, logits = predictor.predict(
        point_coords=input_point,
        point_labels=input_label,
        multimask_output=False,
    )

    # Visualize the results
    for i, (mask, score) in enumerate(zip(masks, scores)):
        plt.figure(figsize=(10, 10))
        plt.imshow(detected_image)
        show_mask(mask, plt.gca())
        show_points(input_point, input_label, plt.gca())
        plt.title(f"Mask {i + 1}, Score: {score:.3f}", fontsize=18)
        plt.axis('off')
        plt.show()

# %%
# Usage example
sam_checkpoint = "C:/Users/Baron/Desktop/EE_267_Repo/EE_267/%PATH_EE267%/EE267_env/checkpoint/sam_vit_h_4b8939.pth"

detect_and_segment_swimmer(r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp\backstroke_video_frame_00502_pp.jpg", sam_checkpoint)

# %% [markdown]
# ### Swimmer Segmentation FINAL

# %%
import torch
from torchvision import models, transforms
import torchvision
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
from segment_anything import sam_model_registry, SamPredictor

# %%
def segment_swimmer_images(input_folder, output_folder, sam_checkpoint, model_type="vit_h", device="cpu"):
    """
    Processes images in the input folder, applies swimmer detection and segmentation,
    and saves the results in the output folder.

    Parameters:
    - input_folder: Folder containing input images.
    - output_folder: Folder to save the segmented images.
    - sam_checkpoint: Path to the SAM model checkpoint.
    - model_type: SAM model type (default: "vit_h").
    - device: Device to run the SAM model on (default: "cpu").
    """
    # Load SAM model for segmentation
    sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
    sam.to(device=device)
    predictor = SamPredictor(sam)
    
    # Check if the output folder exists, and if so, clear it
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)  # Remove all existing files in the folder
    os.makedirs(output_folder)  # Re-create the empty folder
    
    for filename in os.listdir(input_folder):
        image_path = os.path.join(input_folder, filename)
        
        # Detect swimmer in the image using BlazePose
        input_point, image = detect_swimmer_with_blazepose(image_path)
        
        if input_point is None or image is None:
            print(f"No swimmer detected in {filename}. Skipping...")
            continue  # Skip this image if no swimmer detected
        
        input_label = np.array([1])  # Label 1 for positive point

        # Convert to RGB for SAM model
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        predictor.set_image(image_rgb)
        
        # Use SAM for segmentation with multimask_output set to False
        masks, scores, logits = predictor.predict(
            point_coords=input_point,
            point_labels=input_label,
            multimask_output=False  # Produce multiple masks
        )

        # Apply the mask to the image
        mask = masks[0]  # Retrieve the single mask
        mask_image = image_rgb * mask[..., np.newaxis]
        mask_image_bgr = cv2.cvtColor(mask_image, cv2.COLOR_RGB2BGR)
        
        # Save the segmented image
        output_filename = f"{os.path.splitext(filename)[0]}_segmented.jpg"
        output_path = os.path.join(output_folder, output_filename)
        cv2.imwrite(output_path, mask_image_bgr)
        print(f"Saved segmented image {output_filename}")

# %%
# Usage example
sam_checkpoint = "C:/Users/Baron/Desktop/EE_267_Repo/EE_267/%PATH_EE267%/EE267_env/checkpoint/sam_vit_h_4b8939.pth"

#Preprocessed Locations
backstroke_pictures_location_pp = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\backstroke_pictures_pp" 
breathstroke_pictures_location_pp = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\breathstroke_pictures_pp" 
butterfly_pictures_location_pp = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\pre_processed\butterfly_pictures_pp"  


## Endpoint Folders
backstroke_pictures_location_seg = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\segmented\backstroke_pictures_seg" 
breathstroke_pictures_location_seg = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\segmented\breathstroke_pictures_seg" 
butterfly_pictures_location_seg = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\segmented\butterfly_pictures_seg"  


segment_swimmer_images(backstroke_pictures_location_pp, backstroke_pictures_location_seg, sam_checkpoint)
#segment_swimmer_images(breathstroke_pictures_location_raw, breathstroke_pictures_location_seg, sam_checkpoint)
#segment_swimmer_images(butterfly_pictures_location_raw, butterfly_pictures_location_seg, sam_checkpoint)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[170], line 16
#      12 breathstroke_pictures_location_seg = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\segmented\breathstroke_pictures_seg"
#      13 butterfly_pictures_location_seg = r"C:\Users\Baron\Documents\Grad_School\EE_267\term_project\pictures\videos_to_pictures\segmented\butterfly_pictures_seg"
# ---> 16 segment_swimmer_images(backstroke_pictures_location_pp, backstroke_pictures_location_seg, sam_checkpoint)
#
# Cell In[162], line 14, in segment_swimmer_images(input_folder, output_folder, sam_checkpoint, model_type, device)
#       2 """
#       3 Processes images in the input folder, applies swimmer detection and segmentation,
#       4 and saves the results in the output folder.
#    (...)
#      11 - device: Device to run the SAM model on (default: "cpu").
#      12 """
#      13 # Load SAM model for segmentation
# ---> 14 sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
#      15 sam.to(device=device)
#      16 predictor = SamPredictor(sam)
#
# File c:\users\baron\desktop\segment-anything\segment_anything\build_sam.py:15, in build_sam_vit_h(checkpoint)
#      14 def build_sam_vit_h(checkpoint=None):
# ---> 15     return _build_sam(
#      16         encoder_embed_dim=1280,
#      17         encoder_depth=32,
#      18         encoder_num_heads=16,
#      19         encoder_global_attn_indexes=[7, 15, 23, 31],
#      20         checkpoint=checkpoint,
#      21     )
#
# File c:\users\baron\desktop\segment-anything\segment_anything\build_sam.py:67, in _build_sam(encoder_embed_dim, encoder_depth, encoder_num_heads, encoder_global_attn_indexes, checkpoint)
#      64 vit_patch_size = 16
#      65 image_embedding_size = image_size // vit_patch_size
#      66 sam = Sam(
# ---> 67     image_encoder=ImageEncoderViT(
#      68         depth=encoder_depth,
#      69         embed_dim=encoder_embed_dim,
#      70         img_size=image_size,
#      71         mlp_ratio=4,
#      72         norm_layer=partial(torch.nn.LayerNorm, eps=1e-6),
#      73         num_heads=encoder_num_heads,
#      74         patch_size=vit_patch_size,
#      75         qkv_bias=True,
#      76         use_rel_pos=True,
#      77         global_attn_indexes=encoder_global_attn_indexes,
#      78         window_size=14,
#      79         out_chans=prompt_embed_dim,
#      80     ),
#      81     prompt_encoder=PromptEncoder(
#      82         embed_dim=prompt_embed_dim,
#      83         image_embedding_size=(image_embedding_size, image_embedding_size),
#      84         input_image_size=(image_size, image_size),
#      85         mask_in_chans=16,
#      86     ),
#      87     mask_decoder=MaskDecoder(
#      88         num_multimask_outputs=3,
#      89         transformer=TwoWayTransformer(
#      90             depth=2,
#      91             embedding_dim=prompt_embed_dim,
#      92             mlp_dim=2048,
#      93             num_heads=8,
#      94         ),
#      95         transformer_dim=prompt_embed_dim,
#      96         iou_head_depth=3,
#      97         iou_head_hidden_dim=256,
#      98     ),
#      99     pixel_mean=[123.675, 116.28, 103.53],
#     100     pixel_std=[58.395, 57.12, 57.375],
#     101 )
#     102 sam.eval()
#     103 if checkpoint is not None:
#
# File c:\users\baron\desktop\segment-anything\segment_anything\modeling\image_encoder.py:74, in ImageEncoderViT.__init__(self, img_size, patch_size, in_chans, embed_dim, depth, num_heads, mlp_ratio, out_chans, qkv_bias, norm_layer, act_layer, use_abs_pos, use_rel_pos, rel_pos_zero_init, window_size, global_attn_indexes)
#      72 self.blocks = nn.ModuleList()
#      73 for i in range(depth):
# ---> 74     block = Block(
#      75         dim=embed_dim,
#      76         num_heads=num_heads,
#      77         mlp_ratio=mlp_ratio,
#      78         qkv_bias=qkv_bias,
#      79         norm_layer=norm_layer,
#      80         act_layer=act_layer,
#      81         use_rel_pos=use_rel_pos,
#      82         rel_pos_zero_init=rel_pos_zero_init,
#      83         window_size=window_size if i not in global_attn_indexes else 0,
#      84         input_size=(img_size // patch_size, img_size // patch_size),
#      85     )
#      86     self.blocks.append(block)
#      88 self.neck = nn.Sequential(
#      89     nn.Conv2d(
#      90         embed_dim,
#    (...)
#     103     LayerNorm2d(out_chans),
#     104 )
#
# File c:\users\baron\desktop\segment-anything\segment_anything\modeling\image_encoder.py:152, in Block.__init__(self, dim, num_heads, mlp_ratio, qkv_bias, norm_layer, act_layer, use_rel_pos, rel_pos_zero_init, window_size, input_size)
#     150 super().__init__()
#     151 self.norm1 = norm_layer(dim)
# --> 152 self.attn = Attention(
#     153     dim,
#     154     num_heads=num_heads,
#     155     qkv_bias=qkv_bias,
#     156     use_rel_pos=use_rel_pos,
#     157     rel_pos_zero_init=rel_pos_zero_init,
#     158     input_size=input_size if window_size == 0 else (window_size, window_size),
#     159 )
#     161 self.norm2 = norm_layer(dim)
#     162 self.mlp = MLPBlock(embedding_dim=dim, mlp_dim=int(dim * mlp_ratio), act=act_layer)
#
# File c:\users\baron\desktop\segment-anything\segment_anything\modeling\image_encoder.py:212, in Attention.__init__(self, dim, num_heads, qkv_bias, use_rel_pos, rel_pos_zero_init, input_size)
#     209 head_dim = dim // num_heads
#     210 self.scale = head_dim**-0.5
# --> 212 self.qkv = nn.Linear(dim, dim * 3, bias=qkv_bias)
#     213 self.proj = nn.Linear(dim, dim)
#     215 self.use_rel_pos = use_rel_pos
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:112, in Linear.__init__(self, in_features, out_features, bias, device, dtype)
#     110 else:
#     111     self.register_parameter("bias", None)
# --> 112 self.reset_parameters()
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\linear.py:118, in Linear.reset_parameters(self)
#     114 def reset_parameters(self) -> None:
#     115     # Setting a=sqrt(5) in kaiming_uniform is the same as initializing with
#     116     # uniform(-1/sqrt(in_features), 1/sqrt(in_features)). For details, see
#     117     # https://github.com/pytorch/pytorch/issues/57109
# --> 118     init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#     119     if self.bias is not None:
#     120         fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\init.py:518, in kaiming_uniform_(tensor, a, mode, nonlinearity, generator)
#     516 bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
#     517 with torch.no_grad():
# --> 518     return tensor.uniform_(-bound, bound, generator=generator)
#
# KeyboardInterrupt:
